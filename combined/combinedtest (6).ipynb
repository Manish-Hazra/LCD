# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.nasnet import NASNetLarge
from tensorflow.keras.applications.nasnet import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob

# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import matplotlib.image as mplimg
from matplotlib.pyplot import imshow
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from skimage import color
from skimage import io
from skimage.transform import rescale, resize
from keras import layers
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.imagenet_utils import preprocess_input
from keras.layers import Input, Dense, Activation, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalAveragePooling2D
from keras.models import Model
from keras.metrics import categorical_accuracy, top_k_categorical_accuracy, categorical_crossentropy
from keras.callbacks import ModelCheckpoint, EarlyStopping
import keras.backend as K
from keras.models import Sequential
import tensorflow as tf
import warnings

# %%
import os
f=[] 
def listdirs(rootdir):
    for file in os.listdir(rootdir):
        d = os.path.join(rootdir, file)
        if os.path.isdir(d):
            print(d)
            f.append(d)
            listdirs(d)
 
rootdir = '../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets'
listdirs(rootdir)
# Out:
# ../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/lung_aca
# ../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/lung_scc
# ../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/lung_n

# %%
import pandas as pd
from pathlib import Path

image_dir_path = '../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/lung_n'
paths = [path.parts[-3:] for path in
         Path(image_dir_path).rglob('*.jpeg')]
df1 = pd.DataFrame(data=paths, columns=['Root', 'Type', 'Images'])
print(df1)


image_dir_path = '../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/lung_scc'
paths = [path.parts[-3:] for path in
         Path(image_dir_path).rglob('*.jpeg')]
df2 = pd.DataFrame(data=paths, columns=['Root', 'Type', 'Images'])
print(df2)
image_dir_path ='../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/lung_aca'
paths = [path.parts[-3:] for path in
         Path(image_dir_path).rglob('*.jpeg')]
df3 = pd.DataFrame(data=paths, columns=['Root', 'Type', 'Images'])
print(df3)
# Out:
#                  Root    Type          Images
# 0     lung_image_sets  lung_n   lungn691.jpeg
# 1     lung_image_sets  lung_n  lungn3098.jpeg
# 2     lung_image_sets  lung_n  lungn4225.jpeg
# 3     lung_image_sets  lung_n    lungn40.jpeg
# 4     lung_image_sets  lung_n  lungn4213.jpeg
# ...               ...     ...             ...
# 4995  lung_image_sets  lung_n  lungn1469.jpeg
# 4996  lung_image_sets  lung_n  lungn1508.jpeg
# 4997  lung_image_sets  lung_n  lungn1966.jpeg
# 4998  lung_image_sets  lung_n  lungn4090.jpeg
# 4999  lung_image_sets  lung_n   lungn554.jpeg
#
# [5000 rows x 3 columns]
#                  Root      Type            Images
# 0     lung_image_sets  lung_scc  lungscc1930.jpeg
# 1     lung_image_sets  lung_scc  lungscc1441.jpeg
# 2     lung_image_sets  lung_scc  lungscc4624.jpeg
# 3     lung_image_sets  lung_scc  lungscc4038.jpeg
# 4     lung_image_sets  lung_scc  lungscc2504.jpeg
# ...               ...       ...               ...
# 4995  lung_image_sets  lung_scc  lungscc3958.jpeg
# 4996  lung_image_sets  lung_scc   lungscc770.jpeg
# 4997  lung_image_sets  lung_scc  lungscc4614.jpeg
# 4998  lung_image_sets  lung_scc  lungscc3515.jpeg
# 4999  lung_image_sets  lung_scc  lungscc1826.jpeg
#
# [5000 rows x 3 columns]
#                  Root      Type            Images
# 0     lung_image_sets  lung_aca  lungaca2056.jpeg
# 1     lung_image_sets  lung_aca  lungaca1914.jpeg
# 2     lung_image_sets  lung_aca  lungaca3989.jpeg
# 3     lung_image_sets  lung_aca  lungaca3803.jpeg
# 4     lung_image_sets  lung_aca   lungaca861.jpeg
# ...               ...       ...               ...
# 4995  lung_image_sets  lung_aca  lungaca3823.jpeg
# 4996  lung_image_sets  lung_aca  lungaca2457.jpeg
# 4997  lung_image_sets  lung_aca  lungaca4147.jpeg
# 4998  lung_image_sets  lung_aca  lungaca1477.jpeg
# 4999  lung_image_sets  lung_aca  lungaca3216.jpeg
#
# [5000 rows x 3 columns]

# %%
df = pd.concat([df1,df2,df3])
df.reset_index()
# Out:
#        index             Root      Type            Images
# 0          0  lung_image_sets    lung_n     lungn691.jpeg
# 1          1  lung_image_sets    lung_n    lungn3098.jpeg
# 2          2  lung_image_sets    lung_n    lungn4225.jpeg
# 3          3  lung_image_sets    lung_n      lungn40.jpeg
# 4          4  lung_image_sets    lung_n    lungn4213.jpeg
# ...      ...              ...       ...               ...
# 14995   4995  lung_image_sets  lung_aca  lungaca3823.jpeg
# 14996   4996  lung_image_sets  lung_aca  lungaca2457.jpeg
# 14997   4997  lung_image_sets  lung_aca  lungaca4147.jpeg
# 14998   4998  lung_image_sets  lung_aca  lungaca1477.jpeg
# 14999   4999  lung_image_sets  lung_aca  lungaca3216.jpeg
#
# [15000 rows x 4 columns]

# %%
import os
os.makedirs('/kaggle/working/cmyk/lung_n')
os.makedirs('/kaggle/working/cmyk/lung_scc')
os.makedirs('/kaggle/working/cmyk/lung_aca')
os.makedirs('/kaggle/working/ycbcr/lung_n')
os.makedirs('/kaggle/working/ycbcr/lung_scc')
os.makedirs('/kaggle/working/ycbcr/lung_aca')

# %%
y = df.filter(['Type'])

# %%
y
# Out:
#           Type
# 0       lung_n
# 1       lung_n
# 2       lung_n
# 3       lung_n
# 4       lung_n
# ...        ...
# 4995  lung_aca
# 4996  lung_aca
# 4997  lung_aca
# 4998  lung_aca
# 4999  lung_aca
#
# [15000 rows x 1 columns]

# %%
from zipfile import ZipFile
from PIL import Image
import os
def prepareImages(data, m, dataset):
    img_size=331
    print("Preparing images")
    X_train = np.zeros((m, img_size, img_size, 1))
    count = 0
    p=0
    for index,row in df.iterrows():
        img = image.load_img(r"../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/"+row["Type"]+"/"+row["Images"])
        img_rgb = Image.open(r"../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/"+row["Type"]+"/"+row["Images"])
        img_cmyk = img_rgb.convert('CMYK')
        img_ycbcr = img_rgb.convert('YCbCr')
        img_cmyk.save(r"./cmyk/"+y['Type'].values[count]+"/"+"processed"+str(count)+".jpeg")
        img_ycbcr.save(r"./ycbcr/"+y['Type'].values[count]+"/"+"processed"+str(count)+".jpeg")
        count += 1
        print(index)
        print(row)
        print(count)

# %%
df.shape[0]
# Out:
# 15000

# %%
prepareImages(df, df.shape[0], "train")
# Out:
# 1917
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3636.jpeg
# Name: 1917, dtype: object
# 1918
# 1918
# Root      lung_image_sets
# Type               lung_n
# Images       lungn38.jpeg
# Name: 1918, dtype: object
# 1919
# 1919
# Root      lung_image_sets
# Type               lung_n
# Images       lungn46.jpeg
# Name: 1919, dtype: object
# 1920
# 1920
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1674.jpeg
# Name: 1920, dtype: object
# 1921
# 1921
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3345.jpeg
# Name: 1921, dtype: object
# 1922
# 1922
# Root      lung_image_sets
# Type               lung_n
# Images      lungn867.jpeg
# Name: 1922, dtype: object
# 1923
# 1923
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4460.jpeg
# Name: 1923, dtype: object
# 1924
# 1924
# Root      lung_image_sets
# Type               lung_n
# Images      lungn830.jpeg
# Name: 1924, dtype: object
# 1925
# 1925
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3520.jpeg
# Name: 1925, dtype: object
# 1926
# 1926
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3145.jpeg
# Name: 1926, dtype: object
# 1927
# 1927
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2993.jpeg
# Name: 1927, dtype: object
# 1928
# 1928
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4008.jpeg
# Name: 1928, dtype: object
# 1929
# 1929
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1992.jpeg
# Name: 1929, dtype: object
# 1930
# 1930
# Root      lung_image_sets
# Type               lung_n
# Images      lungn190.jpeg
# Name: 1930, dtype: object
# 1931
# 1931
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2362.jpeg
# Name: 1931, dtype: object
# 1932
# 1932
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2642.jpeg
# Name: 1932, dtype: object
# 1933
# 1933
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3532.jpeg
# Name: 1933, dtype: object
# 1934
# 1934
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1355.jpeg
# Name: 1934, dtype: object
# 1935
# 1935
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4724.jpeg
# Name: 1935, dtype: object
# 1936
# 1936
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3841.jpeg
# Name: 1936, dtype: object
# 1937
# 1937
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2426.jpeg
# Name: 1937, dtype: object
# 1938
# 1938
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2676.jpeg
# Name: 1938, dtype: object
# 1939
# 1939
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4239.jpeg
# Name: 1939, dtype: object
# 1940
# 1940
# Root      lung_image_sets
# Type               lung_n
# Images      lungn668.jpeg
# Name: 1940, dtype: object
# 1941
# 1941
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4573.jpeg
# Name: 1941, dtype: object
# 1942
# 1942
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1444.jpeg
# Name: 1942, dtype: object
# 1943
# 1943
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1455.jpeg
# Name: 1943, dtype: object
# 1944
# 1944
# Root      lung_image_sets
# Type               lung_n
# Images      lungn802.jpeg
# Name: 1944, dtype: object
# 1945
# 1945
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3749.jpeg
# Name: 1945, dtype: object
# 1946
# 1946
# Root      lung_image_sets
# Type               lung_n
# Images      lungn661.jpeg
# Name: 1946, dtype: object
# 1947
# 1947
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4669.jpeg
# Name: 1947, dtype: object
# 1948
# 1948
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2074.jpeg
# Name: 1948, dtype: object
# 1949
# 1949
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2363.jpeg
# Name: 1949, dtype: object
# 1950
# 1950
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1614.jpeg
# Name: 1950, dtype: object
# 1951
# 1951
# Root      lung_image_sets
# Type               lung_n
# Images      lungn470.jpeg
# Name: 1951, dtype: object
# 1952
# 1952
# Root      lung_image_sets
# Type               lung_n
# Images      lungn885.jpeg
# Name: 1952, dtype: object
# 1953
# 1953
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3732.jpeg
# Name: 1953, dtype: object
# 1954
# 1954
# Root      lung_image_sets
# Type               lung_n
# Images      lungn587.jpeg
# Name: 1954, dtype: object
# 1955
# 1955
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1262.jpeg
# Name: 1955, dtype: object
# 1956
# 1956
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3488.jpeg
# Name: 1956, dtype: object
# 1957
# 1957
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2274.jpeg
# Name: 1957, dtype: object
# 1958
# 1958
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3057.jpeg
# Name: 1958, dtype: object
# 1959
# 1959
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4153.jpeg
# Name: 1959, dtype: object
# 1960
# 1960
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1598.jpeg
# Name: 1960, dtype: object
# 1961
# 1961
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3719.jpeg
# Name: 1961, dtype: object
# 1962
# 1962
# Root      lung_image_sets
# Type               lung_n
# Images      lungn658.jpeg
# Name: 1962, dtype: object
# 1963
# 1963
# Root      lung_image_sets
# Type               lung_n
# Images      lungn895.jpeg
# Name: 1963, dtype: object
# 1964
# 1964
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1027.jpeg
# Name: 1964, dtype: object
# 1965
# 1965
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3446.jpeg
# Name: 1965, dtype: object
# 1966
# 1966
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2751.jpeg
# Name: 1966, dtype: object
# 1967
# 1967
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3208.jpeg
# Name: 1967, dtype: object
# 1968
# 1968
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1113.jpeg
# Name: 1968, dtype: object
# 1969
# 1969
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1178.jpeg
# Name: 1969, dtype: object
# 1970
# 1970
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2289.jpeg
# Name: 1970, dtype: object
# 1971
# 1971
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1199.jpeg
# Name: 1971, dtype: object
# 1972
# 1972
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3463.jpeg
# Name: 1972, dtype: object
# 1973
# 1973
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2323.jpeg
# Name: 1973, dtype: object
# 1974
# 1974
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2321.jpeg
# Name: 1974, dtype: object
# 1975
# 1975
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3031.jpeg
# Name: 1975, dtype: object
# 1976
# 1976
# Root      lung_image_sets
# Type               lung_n
# Images      lungn816.jpeg
# Name: 1976, dtype: object
# 1977
# 1977
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2588.jpeg
# Name: 1977, dtype: object
# 1978
# 1978
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1287.jpeg
# Name: 1978, dtype: object
# 1979
# 1979
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3278.jpeg
# Name: 1979, dtype: object
# 1980
# 1980
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4785.jpeg
# Name: 1980, dtype: object
# 1981
# 1981
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1564.jpeg
# Name: 1981, dtype: object
# 1982
# 1982
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3555.jpeg
# Name: 1982, dtype: object
# 1983
# 1983
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1712.jpeg
# Name: 1983, dtype: object
# 1984
# 1984
# Root      lung_image_sets
# Type               lung_n
# Images      lungn642.jpeg
# Name: 1984, dtype: object
# 1985
# 1985
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3125.jpeg
# Name: 1985, dtype: object
# 1986
# 1986
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3515.jpeg
# Name: 1986, dtype: object
# 1987
# 1987
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4801.jpeg
# Name: 1987, dtype: object
# 1988
# 1988
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2154.jpeg
# Name: 1988, dtype: object
# 1989
# 1989
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4924.jpeg
# Name: 1989, dtype: object
# 1990
# 1990
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2461.jpeg
# Name: 1990, dtype: object
# 1991
# 1991
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2133.jpeg
# Name: 1991, dtype: object
# 1992
# 1992
# Root      lung_image_sets
# Type               lung_n
# Images      lungn613.jpeg
# Name: 1992, dtype: object
# 1993
# 1993
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2503.jpeg
# Name: 1993, dtype: object
# 1994
# 1994
# Root      lung_image_sets
# Type               lung_n
# Images      lungn875.jpeg
# Name: 1994, dtype: object
# 1995
# 1995
# Root      lung_image_sets
# Type               lung_n
# Images      lungn838.jpeg
# Name: 1995, dtype: object
# 1996
# 1996
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4534.jpeg
# Name: 1996, dtype: object
# 1997
# 1997
# Root      lung_image_sets
# Type               lung_n
# Images      lungn690.jpeg
# Name: 1997, dtype: object
# 1998
# 1998
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2045.jpeg
# Name: 1998, dtype: object
# 1999
# 1999
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1921.jpeg
# Name: 1999, dtype: object
# 2000
# 2000
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1059.jpeg
# Name: 2000, dtype: object
# 2001
# 2001
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2823.jpeg
# Name: 2001, dtype: object
# 2002
# 2002
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3353.jpeg
# Name: 2002, dtype: object
# 2003
# 2003
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4433.jpeg
# Name: 2003, dtype: object
# 2004
# 2004
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2246.jpeg
# Name: 2004, dtype: object
# 2005
# 2005
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3088.jpeg
# Name: 2005, dtype: object
# 2006
# 2006
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2634.jpeg
# Name: 2006, dtype: object
# 2007
# 2007
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3147.jpeg
# Name: 2007, dtype: object
# 2008
# 2008
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4432.jpeg
# Name: 2008, dtype: object
# 2009
# 2009
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4149.jpeg
# Name: 2009, dtype: object
# 2010
# 2010
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4781.jpeg
# Name: 2010, dtype: object
# 2011
# 2011
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3085.jpeg
# Name: 2011, dtype: object
# 2012
# 2012
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4854.jpeg
# Name: 2012, dtype: object
# 2013
# 2013
# Root      lung_image_sets
# Type               lung_n
# Images      lungn814.jpeg
# Name: 2013, dtype: object
# 2014
# 2014
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4091.jpeg
# Name: 2014, dtype: object
# 2015
# 2015
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1986.jpeg
# Name: 2015, dtype: object
# 2016
# 2016
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4443.jpeg
# Name: 2016, dtype: object
# 2017
# 2017
# Root      lung_image_sets
# Type               lung_n
# Images      lungn556.jpeg
# Name: 2017, dtype: object
# 2018
# 2018
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3076.jpeg
# Name: 2018, dtype: object
# 2019
# 2019
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4019.jpeg
# Name: 2019, dtype: object
# 2020
# 2020
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4994.jpeg
# Name: 2020, dtype: object
# 2021
# 2021
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2729.jpeg
# Name: 2021, dtype: object
# 2022
# 2022
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4238.jpeg
# Name: 2022, dtype: object
# 2023
# 2023
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3044.jpeg
# Name: 2023, dtype: object
# 2024
# 2024
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1311.jpeg
# Name: 2024, dtype: object
# 2025
# 2025
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4327.jpeg
# Name: 2025, dtype: object
# 2026
# 2026
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1446.jpeg
# Name: 2026, dtype: object
# 2027
# 2027
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3158.jpeg
# Name: 2027, dtype: object
# 2028
# 2028
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2679.jpeg
# Name: 2028, dtype: object
# 2029
# 2029
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2240.jpeg
# Name: 2029, dtype: object
# 2030
# 2030
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2704.jpeg
# Name: 2030, dtype: object
# 2031
# 2031
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3288.jpeg
# Name: 2031, dtype: object
# 2032
# 2032
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3224.jpeg
# Name: 2032, dtype: object
# 2033
# 2033
# Root      lung_image_sets
# Type               lung_n
# Images      lungn226.jpeg
# Name: 2033, dtype: object
# 2034
# 2034
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1487.jpeg
# Name: 2034, dtype: object
# 2035
# 2035
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4312.jpeg
# Name: 2035, dtype: object
# 2036
# 2036
# Root      lung_image_sets
# Type               lung_n
# Images      lungn530.jpeg
# Name: 2036, dtype: object
# 2037
# 2037
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2436.jpeg
# Name: 2037, dtype: object
# 2038
# 2038
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4482.jpeg
# Name: 2038, dtype: object
# 2039
# 2039
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4585.jpeg
# Name: 2039, dtype: object
# 2040
# 2040
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1155.jpeg
# Name: 2040, dtype: object
# 2041
# 2041
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2474.jpeg
# Name: 2041, dtype: object
# 2042
# 2042
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4587.jpeg
# Name: 2042, dtype: object
# 2043
# 2043
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4052.jpeg
# Name: 2043, dtype: object
# 2044
# 2044
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4584.jpeg
# Name: 2044, dtype: object
# 2045
# 2045
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4513.jpeg
# Name: 2045, dtype: object
# 2046
# 2046
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4586.jpeg
# Name: 2046, dtype: object
# 2047
# 2047
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3342.jpeg
# Name: 2047, dtype: object
# 2048
# 2048
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4461.jpeg
# Name: 2048, dtype: object
# 2049
# 2049
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4144.jpeg
# Name: 2049, dtype: object
# 2050
# 2050
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4038.jpeg
# Name: 2050, dtype: object
# 2051
# 2051
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4976.jpeg
# Name: 2051, dtype: object
# 2052
# 2052
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3537.jpeg
# Name: 2052, dtype: object
# 2053
# 2053
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3489.jpeg
# Name: 2053, dtype: object
# 2054
# 2054
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3413.jpeg
# Name: 2054, dtype: object
# 2055
# 2055
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3102.jpeg
# Name: 2055, dtype: object
# 2056
# 2056
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2171.jpeg
# Name: 2056, dtype: object
# 2057
# 2057
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4285.jpeg
# Name: 2057, dtype: object
# 2058
# 2058
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2320.jpeg
# Name: 2058, dtype: object
# 2059
# 2059
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1180.jpeg
# Name: 2059, dtype: object
# 2060
# 2060
# Root      lung_image_sets
# Type               lung_n
# Images      lungn258.jpeg
# Name: 2060, dtype: object
# 2061
# 2061
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3385.jpeg
# Name: 2061, dtype: object
# 2062
# 2062
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2618.jpeg
# Name: 2062, dtype: object
# 2063
# 2063
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2216.jpeg
# Name: 2063, dtype: object
# 2064
# 2064
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3041.jpeg
# Name: 2064, dtype: object
# 2065
# 2065
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2121.jpeg
# Name: 2065, dtype: object
# 2066
# 2066
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3827.jpeg
# Name: 2066, dtype: object
# 2067
# 2067
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3730.jpeg
# Name: 2067, dtype: object
# 2068
# 2068
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4293.jpeg
# Name: 2068, dtype: object
# 2069
# 2069
# Root      lung_image_sets
# Type               lung_n
# Images      lungn232.jpeg
# Name: 2069, dtype: object
# 2070
# 2070
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3961.jpeg
# Name: 2070, dtype: object
# 2071
# 2071
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3440.jpeg
# Name: 2071, dtype: object
# 2072
# 2072
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2854.jpeg
# Name: 2072, dtype: object
# 2073
# 2073
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1519.jpeg
# Name: 2073, dtype: object
# 2074
# 2074
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1505.jpeg
# Name: 2074, dtype: object
# 2075
# 2075
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2375.jpeg
# Name: 2075, dtype: object
# 2076
# 2076
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4532.jpeg
# Name: 2076, dtype: object
# 2077
# 2077
# Root      lung_image_sets
# Type               lung_n
# Images      lungn222.jpeg
# Name: 2077, dtype: object
# 2078
# 2078
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2695.jpeg
# Name: 2078, dtype: object
# 2079
# 2079
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2874.jpeg
# Name: 2079, dtype: object
# 2080
# 2080
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2554.jpeg
# Name: 2080, dtype: object
# 2081
# 2081
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2105.jpeg
# Name: 2081, dtype: object
# 2082
# 2082
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1807.jpeg
# Name: 2082, dtype: object
# 2083
# 2083
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4466.jpeg
# Name: 2083, dtype: object
# 2084
# 2084
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1383.jpeg
# Name: 2084, dtype: object
# 2085
# 2085
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4190.jpeg
# Name: 2085, dtype: object
# 2086
# 2086
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2804.jpeg
# Name: 2086, dtype: object
# 2087
# 2087
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1651.jpeg
# Name: 2087, dtype: object
# 2088
# 2088
# Root      lung_image_sets
# Type               lung_n
# Images      lungn314.jpeg
# Name: 2088, dtype: object
# 2089
# 2089
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2871.jpeg
# Name: 2089, dtype: object
# 2090
# 2090
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4370.jpeg
# Name: 2090, dtype: object
# 2091
# 2091
# Root      lung_image_sets
# Type               lung_n
# Images      lungn520.jpeg
# Name: 2091, dtype: object
# 2092
# 2092
# Root      lung_image_sets
# Type               lung_n
# Images      lungn490.jpeg
# Name: 2092, dtype: object
# 2093
# 2093
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3490.jpeg
# Name: 2093, dtype: object
# 2094
# 2094
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2981.jpeg
# Name: 2094, dtype: object
# 2095
# 2095
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4683.jpeg
# Name: 2095, dtype: object
# 2096
# 2096
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2358.jpeg
# Name: 2096, dtype: object
# 2097
# 2097
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1176.jpeg
# Name: 2097, dtype: object
# 2098
# 2098
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3811.jpeg
# Name: 2098, dtype: object
# 2099
# 2099
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3265.jpeg
# Name: 2099, dtype: object
# 2100
# 2100
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1975.jpeg
# Name: 2100, dtype: object
# 2101
# 2101
# Root      lung_image_sets
# Type               lung_n
# Images       lungn42.jpeg
# Name: 2101, dtype: object
# 2102
# 2102
# Root      lung_image_sets
# Type               lung_n
# Images      lungn421.jpeg
# Name: 2102, dtype: object
# 2103
# 2103
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1158.jpeg
# Name: 2103, dtype: object
# 2104
# 2104
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1129.jpeg
# Name: 2104, dtype: object
# 2105
# 2105
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3794.jpeg
# Name: 2105, dtype: object
# 2106
# 2106
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1008.jpeg
# Name: 2106, dtype: object
# 2107
# 2107
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4374.jpeg
# Name: 2107, dtype: object
# 2108
# 2108
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1198.jpeg
# Name: 2108, dtype: object
# 2109
# 2109
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3934.jpeg
# Name: 2109, dtype: object
# 2110
# 2110
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3253.jpeg
# Name: 2110, dtype: object
# 2111
# 2111
# Root      lung_image_sets
# Type               lung_n
# Images      lungn111.jpeg
# Name: 2111, dtype: object
# 2112
# 2112
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1090.jpeg
# Name: 2112, dtype: object
# 2113
# 2113
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2559.jpeg
# Name: 2113, dtype: object
# 2114
# 2114
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3344.jpeg
# Name: 2114, dtype: object
# 2115
# 2115
# Root      lung_image_sets
# Type               lung_n
# Images      lungn308.jpeg
# Name: 2115, dtype: object
# 2116
# 2116
# Root      lung_image_sets
# Type               lung_n
# Images      lungn902.jpeg
# Name: 2116, dtype: object
# 2117
# 2117
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4124.jpeg
# Name: 2117, dtype: object
# 2118
# 2118
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3002.jpeg
# Name: 2118, dtype: object
# 2119
# 2119
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4977.jpeg
# Name: 2119, dtype: object
# 2120
# 2120
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1512.jpeg
# Name: 2120, dtype: object
# 2121
# 2121
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1845.jpeg
# Name: 2121, dtype: object
# 2122
# 2122
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4735.jpeg
# Name: 2122, dtype: object
# 2123
# 2123
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4218.jpeg
# Name: 2123, dtype: object
# 2124
# 2124
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4803.jpeg
# Name: 2124, dtype: object
# 2125
# 2125
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1699.jpeg
# Name: 2125, dtype: object
# 2126
# 2126
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1229.jpeg
# Name: 2126, dtype: object
# 2127
# 2127
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2876.jpeg
# Name: 2127, dtype: object
# 2128
# 2128
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4993.jpeg
# Name: 2128, dtype: object
# 2129
# 2129
# Root      lung_image_sets
# Type               lung_n
# Images      lungn223.jpeg
# Name: 2129, dtype: object
# 2130
# 2130
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4248.jpeg
# Name: 2130, dtype: object
# 2131
# 2131
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3004.jpeg
# Name: 2131, dtype: object
# 2132
# 2132
# Root      lung_image_sets
# Type               lung_n
# Images        lungn3.jpeg
# Name: 2132, dtype: object
# 2133
# 2133
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1218.jpeg
# Name: 2133, dtype: object
# 2134
# 2134
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3048.jpeg
# Name: 2134, dtype: object
# 2135
# 2135
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1068.jpeg
# Name: 2135, dtype: object
# 2136
# 2136
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3198.jpeg
# Name: 2136, dtype: object
# 2137
# 2137
# Root      lung_image_sets
# Type               lung_n
# Images      lungn350.jpeg
# Name: 2137, dtype: object
# 2138
# 2138
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4436.jpeg
# Name: 2138, dtype: object
# 2139
# 2139
# Root      lung_image_sets
# Type               lung_n
# Images      lungn560.jpeg
# Name: 2139, dtype: object
# 2140
# 2140
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4612.jpeg
# Name: 2140, dtype: object
# 2141
# 2141
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4257.jpeg
# Name: 2141, dtype: object
# 2142
# 2142
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1151.jpeg
# Name: 2142, dtype: object
# 2143
# 2143
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1007.jpeg
# Name: 2143, dtype: object
# 2144
# 2144
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3060.jpeg
# Name: 2144, dtype: object
# 2145
# 2145
# Root      lung_image_sets
# Type               lung_n
# Images      lungn929.jpeg
# Name: 2145, dtype: object
# 2146
# 2146
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1285.jpeg
# Name: 2146, dtype: object
# 2147
# 2147
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3658.jpeg
# Name: 2147, dtype: object
# 2148
# 2148
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1940.jpeg
# Name: 2148, dtype: object
# 2149
# 2149
# Root      lung_image_sets
# Type               lung_n
# Images      lungn565.jpeg
# Name: 2149, dtype: object
# 2150
# 2150
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4934.jpeg
# Name: 2150, dtype: object
# 2151
# 2151
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1653.jpeg
# Name: 2151, dtype: object
# 2152
# 2152
# Root      lung_image_sets
# Type               lung_n
# Images      lungn179.jpeg
# Name: 2152, dtype: object
# 2153
# 2153
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2272.jpeg
# Name: 2153, dtype: object
# 2154
# 2154
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2680.jpeg
# Name: 2154, dtype: object
# 2155
# 2155
# Root      lung_image_sets
# Type               lung_n
# Images      lungn656.jpeg
# Name: 2155, dtype: object
# 2156
# 2156
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2909.jpeg
# Name: 2156, dtype: object
# 2157
# 2157
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1434.jpeg
# Name: 2157, dtype: object
# 2158
# 2158
# Root      lung_image_sets
# Type               lung_n
# Images      lungn371.jpeg
# Name: 2158, dtype: object
# 2159
# 2159
# Root      lung_image_sets
# Type               lung_n
# Images      lungn486.jpeg
# Name: 2159, dtype: object
# 2160
# 2160
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2621.jpeg
# Name: 2160, dtype: object
# 2161
# 2161
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3374.jpeg
# Name: 2161, dtype: object
# 2162
# 2162
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1204.jpeg
# Name: 2162, dtype: object
# 2163
# 2163
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2156.jpeg
# Name: 2163, dtype: object
# 2164
# 2164
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2987.jpeg
# Name: 2164, dtype: object
# 2165
# 2165
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1638.jpeg
# Name: 2165, dtype: object
# 2166
# 2166
# Root      lung_image_sets
# Type               lung_n
# Images      lungn390.jpeg
# Name: 2166, dtype: object
# 2167
# 2167
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4027.jpeg
# Name: 2167, dtype: object
# 2168
# 2168
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1034.jpeg
# Name: 2168, dtype: object
# 2169
# 2169
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2668.jpeg
# Name: 2169, dtype: object
# 2170
# 2170
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4259.jpeg
# Name: 2170, dtype: object
# 2171
# 2171
# Root      lung_image_sets
# Type               lung_n
# Images      lungn927.jpeg
# Name: 2171, dtype: object
# 2172
# 2172
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4200.jpeg
# Name: 2172, dtype: object
# 2173
# 2173
# Root      lung_image_sets
# Type               lung_n
# Images      lungn230.jpeg
# Name: 2173, dtype: object
# 2174
# 2174
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1031.jpeg
# Name: 2174, dtype: object
# 2175
# 2175
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3543.jpeg
# Name: 2175, dtype: object
# 2176
# 2176
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4818.jpeg
# Name: 2176, dtype: object
# 2177
# 2177
# Root      lung_image_sets
# Type               lung_n
# Images      lungn104.jpeg
# Name: 2177, dtype: object
# 2178
# 2178
# Root      lung_image_sets
# Type               lung_n
# Images      lungn551.jpeg
# Name: 2178, dtype: object
# 2179
# 2179
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1147.jpeg
# Name: 2179, dtype: object
# 2180
# 2180
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2724.jpeg
# Name: 2180, dtype: object
# 2181
# 2181
# Root      lung_image_sets
# Type               lung_n
# Images      lungn200.jpeg
# Name: 2181, dtype: object
# 2182
# 2182
# Root      lung_image_sets
# Type               lung_n
# Images      lungn349.jpeg
# Name: 2182, dtype: object
# 2183
# 2183
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4473.jpeg
# Name: 2183, dtype: object
# 2184
# 2184
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2913.jpeg
# Name: 2184, dtype: object
# 2185
# 2185
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4867.jpeg
# Name: 2185, dtype: object
# 2186
# 2186
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2910.jpeg
# Name: 2186, dtype: object
# 2187
# 2187
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1089.jpeg
# Name: 2187, dtype: object
# 2188
# 2188
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1258.jpeg
# Name: 2188, dtype: object
# 2189
# 2189
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3584.jpeg
# Name: 2189, dtype: object
# 2190
# 2190
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1324.jpeg
# Name: 2190, dtype: object
# 2191
# 2191
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4729.jpeg
# Name: 2191, dtype: object
# 2192
# 2192
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2150.jpeg
# Name: 2192, dtype: object
# 2193
# 2193
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3708.jpeg
# Name: 2193, dtype: object
# 2194
# 2194
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3399.jpeg
# Name: 2194, dtype: object
# 2195
# 2195
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2354.jpeg
# Name: 2195, dtype: object
# 2196
# 2196
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1013.jpeg
# Name: 2196, dtype: object
# 2197
# 2197
# Root      lung_image_sets
# Type               lung_n
# Images      lungn431.jpeg
# Name: 2197, dtype: object
# 2198
# 2198
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2918.jpeg
# Name: 2198, dtype: object
# 2199
# 2199
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2547.jpeg
# Name: 2199, dtype: object
# 2200
# 2200
# Root      lung_image_sets
# Type               lung_n
# Images      lungn907.jpeg
# Name: 2200, dtype: object
# 2201
# 2201
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2927.jpeg
# Name: 2201, dtype: object
# 2202
# 2202
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3205.jpeg
# Name: 2202, dtype: object
# 2203
# 2203
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3552.jpeg
# Name: 2203, dtype: object
# 2204
# 2204
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1412.jpeg
# Name: 2204, dtype: object
# 2205
# 2205
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3761.jpeg
# Name: 2205, dtype: object
# 2206
# 2206
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2164.jpeg
# Name: 2206, dtype: object
# 2207
# 2207
# Root      lung_image_sets
# Type               lung_n
# Images      lungn823.jpeg
# Name: 2207, dtype: object
# 2208
# 2208
# Root      lung_image_sets
# Type               lung_n
# Images      lungn649.jpeg
# Name: 2208, dtype: object
# 2209
# 2209
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2001.jpeg
# Name: 2209, dtype: object
# 2210
# 2210
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1704.jpeg
# Name: 2210, dtype: object
# 2211
# 2211
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3443.jpeg
# Name: 2211, dtype: object
# 2212
# 2212
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2033.jpeg
# Name: 2212, dtype: object
# 2213
# 2213
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3604.jpeg
# Name: 2213, dtype: object
# 2214
# 2214
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3035.jpeg
# Name: 2214, dtype: object
# 2215
# 2215
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3889.jpeg
# Name: 2215, dtype: object
# 2216
# 2216
# Root      lung_image_sets
# Type               lung_n
# Images      lungn993.jpeg
# Name: 2216, dtype: object
# 2217
# 2217
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4979.jpeg
# Name: 2217, dtype: object
# 2218
# 2218
# Root      lung_image_sets
# Type               lung_n
# Images      lungn369.jpeg
# Name: 2218, dtype: object
# 2219
# 2219
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4117.jpeg
# Name: 2219, dtype: object
# 2220
# 2220
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1862.jpeg
# Name: 2220, dtype: object
# 2221
# 2221
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1616.jpeg
# Name: 2221, dtype: object
# 2222
# 2222
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3962.jpeg
# Name: 2222, dtype: object
# 2223
# 2223
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4519.jpeg
# Name: 2223, dtype: object
# 2224
# 2224
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2689.jpeg
# Name: 2224, dtype: object
# 2225
# 2225
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1995.jpeg
# Name: 2225, dtype: object
# 2226
# 2226
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2238.jpeg
# Name: 2226, dtype: object
# 2227
# 2227
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3798.jpeg
# Name: 2227, dtype: object
# 2228
# 2228
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1344.jpeg
# Name: 2228, dtype: object
# 2229
# 2229
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2809.jpeg
# Name: 2229, dtype: object
# 2230
# 2230
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4388.jpeg
# Name: 2230, dtype: object
# 2231
# 2231
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2640.jpeg
# Name: 2231, dtype: object
# 2232
# 2232
# Root      lung_image_sets
# Type               lung_n
# Images       lungn23.jpeg
# Name: 2232, dtype: object
# 2233
# 2233
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2743.jpeg
# Name: 2233, dtype: object
# 2234
# 2234
# Root      lung_image_sets
# Type               lung_n
# Images       lungn22.jpeg
# Name: 2234, dtype: object
# 2235
# 2235
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2203.jpeg
# Name: 2235, dtype: object
# 2236
# 2236
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4565.jpeg
# Name: 2236, dtype: object
# 2237
# 2237
# Root      lung_image_sets
# Type               lung_n
# Images       lungn32.jpeg
# Name: 2237, dtype: object
# 2238
# 2238
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4231.jpeg
# Name: 2238, dtype: object
# 2239
# 2239
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2532.jpeg
# Name: 2239, dtype: object
# 2240
# 2240
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3926.jpeg
# Name: 2240, dtype: object
# 2241
# 2241
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1843.jpeg
# Name: 2241, dtype: object
# 2242
# 2242
# Root      lung_image_sets
# Type               lung_n
# Images      lungn494.jpeg
# Name: 2242, dtype: object
# 2243
# 2243
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4769.jpeg
# Name: 2243, dtype: object
# 2244
# 2244
# Root      lung_image_sets
# Type               lung_n
# Images      lungn645.jpeg
# Name: 2244, dtype: object
# 2245
# 2245
# Root      lung_image_sets
# Type               lung_n
# Images      lungn819.jpeg
# Name: 2245, dtype: object
# 2246
# 2246
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1654.jpeg
# Name: 2246, dtype: object
# 2247
# 2247
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1223.jpeg
# Name: 2247, dtype: object
# 2248
# 2248
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4013.jpeg
# Name: 2248, dtype: object
# 2249
# 2249
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2601.jpeg
# Name: 2249, dtype: object
# 2250
# 2250
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4397.jpeg
# Name: 2250, dtype: object
# 2251
# 2251
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1678.jpeg
# Name: 2251, dtype: object
# 2252
# 2252
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1060.jpeg
# Name: 2252, dtype: object
# 2253
# 2253
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2519.jpeg
# Name: 2253, dtype: object
# 2254
# 2254
# Root      lung_image_sets
# Type               lung_n
# Images      lungn521.jpeg
# Name: 2254, dtype: object
# 2255
# 2255
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4857.jpeg
# Name: 2255, dtype: object
# 2256
# 2256
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4512.jpeg
# Name: 2256, dtype: object
# 2257
# 2257
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1617.jpeg
# Name: 2257, dtype: object
# 2258
# 2258
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4424.jpeg
# Name: 2258, dtype: object
# 2259
# 2259
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3461.jpeg
# Name: 2259, dtype: object
# 2260
# 2260
# Root      lung_image_sets
# Type               lung_n
# Images      lungn788.jpeg
# Name: 2260, dtype: object
# 2261
# 2261
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2581.jpeg
# Name: 2261, dtype: object
# 2262
# 2262
# Root      lung_image_sets
# Type               lung_n
# Images       lungn56.jpeg
# Name: 2262, dtype: object
# 2263
# 2263
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1064.jpeg
# Name: 2263, dtype: object
# 2264
# 2264
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2262.jpeg
# Name: 2264, dtype: object
# 2265
# 2265
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4679.jpeg
# Name: 2265, dtype: object
# 2266
# 2266
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3684.jpeg
# Name: 2266, dtype: object
# 2267
# 2267
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1062.jpeg
# Name: 2267, dtype: object
# 2268
# 2268
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4656.jpeg
# Name: 2268, dtype: object
# 2269
# 2269
# Root      lung_image_sets
# Type               lung_n
# Images      lungn589.jpeg
# Name: 2269, dtype: object
# 2270
# 2270
# Root      lung_image_sets
# Type               lung_n
# Images      lungn139.jpeg
# Name: 2270, dtype: object
# 2271
# 2271
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1418.jpeg
# Name: 2271, dtype: object
# 2272
# 2272
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1349.jpeg
# Name: 2272, dtype: object
# 2273
# 2273
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2763.jpeg
# Name: 2273, dtype: object
# 2274
# 2274
# Root      lung_image_sets
# Type               lung_n
# Images      lungn663.jpeg
# Name: 2274, dtype: object
# 2275
# 2275
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1165.jpeg
# Name: 2275, dtype: object
# 2276
# 2276
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3581.jpeg
# Name: 2276, dtype: object
# 2277
# 2277
# Root      lung_image_sets
# Type               lung_n
# Images      lungn546.jpeg
# Name: 2277, dtype: object
# 2278
# 2278
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3424.jpeg
# Name: 2278, dtype: object
# 2279
# 2279
# Root      lung_image_sets
# Type               lung_n
# Images       lungn95.jpeg
# Name: 2279, dtype: object
# 2280
# 2280
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3199.jpeg
# Name: 2280, dtype: object
# 2281
# 2281
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4168.jpeg
# Name: 2281, dtype: object
# 2282
# 2282
# Root      lung_image_sets
# Type               lung_n
# Images      lungn753.jpeg
# Name: 2282, dtype: object
# 2283
# 2283
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4850.jpeg
# Name: 2283, dtype: object
# 2284
# 2284
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1959.jpeg
# Name: 2284, dtype: object
# 2285
# 2285
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4332.jpeg
# Name: 2285, dtype: object
# 2286
# 2286
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4162.jpeg
# Name: 2286, dtype: object
# 2287
# 2287
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3971.jpeg
# Name: 2287, dtype: object
# 2288
# 2288
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2419.jpeg
# Name: 2288, dtype: object
# 2289
# 2289
# Root      lung_image_sets
# Type               lung_n
# Images       lungn64.jpeg
# Name: 2289, dtype: object
# 2290
# 2290
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2646.jpeg
# Name: 2290, dtype: object
# 2291
# 2291
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2534.jpeg
# Name: 2291, dtype: object
# 2292
# 2292
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4926.jpeg
# Name: 2292, dtype: object
# 2293
# 2293
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2158.jpeg
# Name: 2293, dtype: object
# 2294
# 2294
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3949.jpeg
# Name: 2294, dtype: object
# 2295
# 2295
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2562.jpeg
# Name: 2295, dtype: object
# 2296
# 2296
# Root      lung_image_sets
# Type               lung_n
# Images       lungn36.jpeg
# Name: 2296, dtype: object
# 2297
# 2297
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4224.jpeg
# Name: 2297, dtype: object
# 2298
# 2298
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1600.jpeg
# Name: 2298, dtype: object
# 2299
# 2299
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1138.jpeg
# Name: 2299, dtype: object
# 2300
# 2300
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4538.jpeg
# Name: 2300, dtype: object
# 2301
# 2301
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4496.jpeg
# Name: 2301, dtype: object
# 2302
# 2302
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4143.jpeg
# Name: 2302, dtype: object
# 2303
# 2303
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4557.jpeg
# Name: 2303, dtype: object
# 2304
# 2304
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3445.jpeg
# Name: 2304, dtype: object
# 2305
# 2305
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4821.jpeg
# Name: 2305, dtype: object
# 2306
# 2306
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4688.jpeg
# Name: 2306, dtype: object
# 2307
# 2307
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1123.jpeg
# Name: 2307, dtype: object
# 2308
# 2308
# Root      lung_image_sets
# Type               lung_n
# Images      lungn300.jpeg
# Name: 2308, dtype: object
# 2309
# 2309
# Root      lung_image_sets
# Type               lung_n
# Images      lungn757.jpeg
# Name: 2309, dtype: object
# 2310
# 2310
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2669.jpeg
# Name: 2310, dtype: object
# 2311
# 2311
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2964.jpeg
# Name: 2311, dtype: object
# 2312
# 2312
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3003.jpeg
# Name: 2312, dtype: object
# 2313
# 2313
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4759.jpeg
# Name: 2313, dtype: object
# 2314
# 2314
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4981.jpeg
# Name: 2314, dtype: object
# 2315
# 2315
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3128.jpeg
# Name: 2315, dtype: object
# 2316
# 2316
# Root      lung_image_sets
# Type               lung_n
# Images     lungn3170.jpeg
# Name: 2316, dtype: object
# 2317
# 2317
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1777.jpeg
# Name: 2317, dtype: object
# 2318
# 2318
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4358.jpeg
# Name: 2318, dtype: object
# 2319
# 2319
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2030.jpeg
# Name: 2319, dtype: object
# 2320
# 2320
# Root      lung_image_sets
# Type               lung_n
# Images      lungn569.jpeg
# Name: 2320, dtype: object
# 2321
# 2321
# Root      lung_image_sets
# Type               lung_n
# Images      lungn680.jpeg
# Name: 2321, dtype: object
# 2322
# 2322
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1521.jpeg
# Name: 2322, dtype: object
# 2323
# 2323
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2744.jpeg
# Name: 2323, dtype: object
# 2324
# 2324
# Root      lung_image_sets
# Type               lung_n
# Images      lungn377.jpeg
# Name: 2324, dtype: object
# 2325
# 2325
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4903.jpeg
# Name: 2325, dtype: object
# 2326
# 2326
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2870.jpeg
# Name: 2326, dtype: object
# 2327
# 2327
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4440.jpeg
# Name: 2327, dtype: object
# 2328
# 2328
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4198.jpeg
# Name: 2328, dtype: object
# 2329
# 2329
# Root      lung_image_sets
# Type               lung_n
# Images      lungn983.jpeg
# Name: 2329, dtype: object
# 2330
# 2330
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4215.jpeg
# Name: 2330, dtype: object
# 2331
# 2331
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2410.jpeg
# Name: 2331, dtype: object
# 2332
# 2332
# Root      lung_image_sets
# Type               lung_n
# Images     lungn4347.jpeg
# Name: 2332, dtype: object
# 2333
# 2333
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2192.jpeg
# Name: 2333, dtype: object
# 2334
# 2334
# Root      lung_image_sets
# Type               lung_n
# Images      lungn998.jpeg
# Name: 2334, dtype: object
# 2335
# 2335
# Root      lung_image_sets
# Type               lung_n
# Images     lungn1757.jpeg
# Name: 2335, dtype: object
# 2336
# 2336
# Root      lung_image_sets
# Type               lung_n
# Images     lungn2122.jpeg
# Name: 2336, dtype: object
# 2337
# 2337
# Root      lung_image_sets
# Type               lung_n
# Images      lungn729.jpeg
# Name: 2337, dtype: object
# 2338
# 2338
# ...
# Name: 2027, dtype: object
# 7028
# 2028
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2369.jpeg
# Name: 2028, dtype: object
# 7029
# 2029
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4545.jpeg
# Name: 2029, dtype: object
# 7030
# 2030
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4420.jpeg
# Name: 2030, dtype: object
# 7031
# 2031
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4198.jpeg
# Name: 2031, dtype: object
# 7032
# 2032
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3895.jpeg
# Name: 2032, dtype: object
# 7033
# 2033
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4712.jpeg
# Name: 2033, dtype: object
# 7034
# 2034
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3042.jpeg
# Name: 2034, dtype: object
# 7035
# 2035
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc836.jpeg
# Name: 2035, dtype: object
# 7036
# 2036
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4610.jpeg
# Name: 2036, dtype: object
# 7037
# 2037
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc796.jpeg
# Name: 2037, dtype: object
# 7038
# 2038
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2386.jpeg
# Name: 2038, dtype: object
# 7039
# 2039
# Root      lung_image_sets
# Type             lung_scc
# Images     lungscc48.jpeg
# Name: 2039, dtype: object
# 7040
# 2040
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2673.jpeg
# Name: 2040, dtype: object
# 7041
# 2041
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4811.jpeg
# Name: 2041, dtype: object
# 7042
# 2042
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2899.jpeg
# Name: 2042, dtype: object
# 7043
# 2043
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4466.jpeg
# Name: 2043, dtype: object
# 7044
# 2044
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1254.jpeg
# Name: 2044, dtype: object
# 7045
# 2045
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4812.jpeg
# Name: 2045, dtype: object
# 7046
# 2046
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc716.jpeg
# Name: 2046, dtype: object
# 7047
# 2047
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4820.jpeg
# Name: 2047, dtype: object
# 7048
# 2048
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3769.jpeg
# Name: 2048, dtype: object
# 7049
# 2049
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2520.jpeg
# Name: 2049, dtype: object
# 7050
# 2050
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1503.jpeg
# Name: 2050, dtype: object
# 7051
# 2051
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3400.jpeg
# Name: 2051, dtype: object
# 7052
# 2052
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1139.jpeg
# Name: 2052, dtype: object
# 7053
# 2053
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3148.jpeg
# Name: 2053, dtype: object
# 7054
# 2054
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2077.jpeg
# Name: 2054, dtype: object
# 7055
# 2055
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1979.jpeg
# Name: 2055, dtype: object
# 7056
# 2056
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc927.jpeg
# Name: 2056, dtype: object
# 7057
# 2057
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc141.jpeg
# Name: 2057, dtype: object
# 7058
# 2058
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2494.jpeg
# Name: 2058, dtype: object
# 7059
# 2059
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2542.jpeg
# Name: 2059, dtype: object
# 7060
# 2060
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc306.jpeg
# Name: 2060, dtype: object
# 7061
# 2061
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2971.jpeg
# Name: 2061, dtype: object
# 7062
# 2062
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3874.jpeg
# Name: 2062, dtype: object
# 7063
# 2063
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1332.jpeg
# Name: 2063, dtype: object
# 7064
# 2064
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1464.jpeg
# Name: 2064, dtype: object
# 7065
# 2065
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4268.jpeg
# Name: 2065, dtype: object
# 7066
# 2066
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1651.jpeg
# Name: 2066, dtype: object
# 7067
# 2067
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc986.jpeg
# Name: 2067, dtype: object
# 7068
# 2068
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1904.jpeg
# Name: 2068, dtype: object
# 7069
# 2069
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4434.jpeg
# Name: 2069, dtype: object
# 7070
# 2070
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2290.jpeg
# Name: 2070, dtype: object
# 7071
# 2071
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1095.jpeg
# Name: 2071, dtype: object
# 7072
# 2072
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1224.jpeg
# Name: 2072, dtype: object
# 7073
# 2073
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2575.jpeg
# Name: 2073, dtype: object
# 7074
# 2074
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc867.jpeg
# Name: 2074, dtype: object
# 7075
# 2075
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2625.jpeg
# Name: 2075, dtype: object
# 7076
# 2076
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2727.jpeg
# Name: 2076, dtype: object
# 7077
# 2077
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1010.jpeg
# Name: 2077, dtype: object
# 7078
# 2078
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3290.jpeg
# Name: 2078, dtype: object
# 7079
# 2079
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2135.jpeg
# Name: 2079, dtype: object
# 7080
# 2080
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1696.jpeg
# Name: 2080, dtype: object
# 7081
# 2081
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2584.jpeg
# Name: 2081, dtype: object
# 7082
# 2082
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc827.jpeg
# Name: 2082, dtype: object
# 7083
# 2083
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc285.jpeg
# Name: 2083, dtype: object
# 7084
# 2084
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4900.jpeg
# Name: 2084, dtype: object
# 7085
# 2085
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2946.jpeg
# Name: 2085, dtype: object
# 7086
# 2086
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4393.jpeg
# Name: 2086, dtype: object
# 7087
# 2087
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2931.jpeg
# Name: 2087, dtype: object
# 7088
# 2088
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc775.jpeg
# Name: 2088, dtype: object
# 7089
# 2089
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3639.jpeg
# Name: 2089, dtype: object
# 7090
# 2090
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc408.jpeg
# Name: 2090, dtype: object
# 7091
# 2091
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4488.jpeg
# Name: 2091, dtype: object
# 7092
# 2092
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3010.jpeg
# Name: 2092, dtype: object
# 7093
# 2093
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4790.jpeg
# Name: 2093, dtype: object
# 7094
# 2094
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3500.jpeg
# Name: 2094, dtype: object
# 7095
# 2095
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4139.jpeg
# Name: 2095, dtype: object
# 7096
# 2096
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3943.jpeg
# Name: 2096, dtype: object
# 7097
# 2097
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc151.jpeg
# Name: 2097, dtype: object
# 7098
# 2098
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3009.jpeg
# Name: 2098, dtype: object
# 7099
# 2099
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2958.jpeg
# Name: 2099, dtype: object
# 7100
# 2100
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3966.jpeg
# Name: 2100, dtype: object
# 7101
# 2101
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1686.jpeg
# Name: 2101, dtype: object
# 7102
# 2102
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc565.jpeg
# Name: 2102, dtype: object
# 7103
# 2103
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2165.jpeg
# Name: 2103, dtype: object
# 7104
# 2104
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4957.jpeg
# Name: 2104, dtype: object
# 7105
# 2105
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3161.jpeg
# Name: 2105, dtype: object
# 7106
# 2106
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4890.jpeg
# Name: 2106, dtype: object
# 7107
# 2107
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc888.jpeg
# Name: 2107, dtype: object
# 7108
# 2108
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1762.jpeg
# Name: 2108, dtype: object
# 7109
# 2109
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3098.jpeg
# Name: 2109, dtype: object
# 7110
# 2110
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3563.jpeg
# Name: 2110, dtype: object
# 7111
# 2111
# Root      lung_image_sets
# Type             lung_scc
# Images     lungscc61.jpeg
# Name: 2111, dtype: object
# 7112
# 2112
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3475.jpeg
# Name: 2112, dtype: object
# 7113
# 2113
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2787.jpeg
# Name: 2113, dtype: object
# 7114
# 2114
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1707.jpeg
# Name: 2114, dtype: object
# 7115
# 2115
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4284.jpeg
# Name: 2115, dtype: object
# 7116
# 2116
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4839.jpeg
# Name: 2116, dtype: object
# 7117
# 2117
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4376.jpeg
# Name: 2117, dtype: object
# 7118
# 2118
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2380.jpeg
# Name: 2118, dtype: object
# 7119
# 2119
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4482.jpeg
# Name: 2119, dtype: object
# 7120
# 2120
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc594.jpeg
# Name: 2120, dtype: object
# 7121
# 2121
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1641.jpeg
# Name: 2121, dtype: object
# 7122
# 2122
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2400.jpeg
# Name: 2122, dtype: object
# 7123
# 2123
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1534.jpeg
# Name: 2123, dtype: object
# 7124
# 2124
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc905.jpeg
# Name: 2124, dtype: object
# 7125
# 2125
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4744.jpeg
# Name: 2125, dtype: object
# 7126
# 2126
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3569.jpeg
# Name: 2126, dtype: object
# 7127
# 2127
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc741.jpeg
# Name: 2127, dtype: object
# 7128
# 2128
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4305.jpeg
# Name: 2128, dtype: object
# 7129
# 2129
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4751.jpeg
# Name: 2129, dtype: object
# 7130
# 2130
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4656.jpeg
# Name: 2130, dtype: object
# 7131
# 2131
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1075.jpeg
# Name: 2131, dtype: object
# 7132
# 2132
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4258.jpeg
# Name: 2132, dtype: object
# 7133
# 2133
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc493.jpeg
# Name: 2133, dtype: object
# 7134
# 2134
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4085.jpeg
# Name: 2134, dtype: object
# 7135
# 2135
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3952.jpeg
# Name: 2135, dtype: object
# 7136
# 2136
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3369.jpeg
# Name: 2136, dtype: object
# 7137
# 2137
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3247.jpeg
# Name: 2137, dtype: object
# 7138
# 2138
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4569.jpeg
# Name: 2138, dtype: object
# 7139
# 2139
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc636.jpeg
# Name: 2139, dtype: object
# 7140
# 2140
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2488.jpeg
# Name: 2140, dtype: object
# 7141
# 2141
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3114.jpeg
# Name: 2141, dtype: object
# 7142
# 2142
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3006.jpeg
# Name: 2142, dtype: object
# 7143
# 2143
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4960.jpeg
# Name: 2143, dtype: object
# 7144
# 2144
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc115.jpeg
# Name: 2144, dtype: object
# 7145
# 2145
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc666.jpeg
# Name: 2145, dtype: object
# 7146
# 2146
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3001.jpeg
# Name: 2146, dtype: object
# 7147
# 2147
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2242.jpeg
# Name: 2147, dtype: object
# 7148
# 2148
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3140.jpeg
# Name: 2148, dtype: object
# 7149
# 2149
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc358.jpeg
# Name: 2149, dtype: object
# 7150
# 2150
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1355.jpeg
# Name: 2150, dtype: object
# 7151
# 2151
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2401.jpeg
# Name: 2151, dtype: object
# 7152
# 2152
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc278.jpeg
# Name: 2152, dtype: object
# 7153
# 2153
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc599.jpeg
# Name: 2153, dtype: object
# 7154
# 2154
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4961.jpeg
# Name: 2154, dtype: object
# 7155
# 2155
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3088.jpeg
# Name: 2155, dtype: object
# 7156
# 2156
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2924.jpeg
# Name: 2156, dtype: object
# 7157
# 2157
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1949.jpeg
# Name: 2157, dtype: object
# 7158
# 2158
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3670.jpeg
# Name: 2158, dtype: object
# 7159
# 2159
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3004.jpeg
# Name: 2159, dtype: object
# 7160
# 2160
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4080.jpeg
# Name: 2160, dtype: object
# 7161
# 2161
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2381.jpeg
# Name: 2161, dtype: object
# 7162
# 2162
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3255.jpeg
# Name: 2162, dtype: object
# 7163
# 2163
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc588.jpeg
# Name: 2163, dtype: object
# 7164
# 2164
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1863.jpeg
# Name: 2164, dtype: object
# 7165

# %%
IMAGE_SIZE = (331, 331, 3)

train_path_rgb = '../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets'
train_path_cmyk = '../working/cmyk/'
train_path_ycbcr = '..working/ycbcr/'

# %%
folders = glob('../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/*')
print(len(folders))

# %%
nasnetL1 = NASNetLarge(input_shape=IMAGE_SIZE, include_top=False, weights="imagenet")
nasnetL2 = NASNetLarge(input_shape=IMAGE_SIZE, include_top=False, weights="imagenet")
nasnetL3 = NASNetLarge(input_shape=IMAGE_SIZE, include_top=False, weights="imagenet")

# %%
for layer in nasnetL1.layers:
    layer.trainable = False
for layer in nasnetL2.layers:
    layer.trainable = False
for layer in nasnetL3.layers:
    layer.trainable = False

# %%
x1 = Flatten()(nasnetL1.output)
x2 = Flatten()(nasnetL2.output)
x3 = Flatten()(nasnetL3.output)

# %%
prediction1 = Dense(len(folders), activation='softmax')(x1)
prediction2 = Dense(len(folders), activation='softmax')(x2)
prediction3 = Dense(len(folders), activation='softmax')(x3)
model1 = Model(inputs=nasnetL1.input, outputs=prediction1)
model2 = Model(inputs=nasnetL2.input, outputs=prediction2)
model3 = Model(inputs=nasnetL3.input, outputs=prediction3)

# %%
model1.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)
model2.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)
model3.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
data1 = ImageDataGenerator(validation_split = 0.2,
                          rescale = 1./224,
                          shear_range = 0.2,
                          zoom_range = 0.2,
                          horizontal_flip = True)
data2 = ImageDataGenerator(validation_split = 0.2,
                          rescale = 1./224,
                          shear_range = 0.2,
                          zoom_range = 0.2,
                          horizontal_flip = True)
data3 = ImageDataGenerator(validation_split = 0.2,
                          rescale = 1./224,
                          shear_range = 0.2,
                          zoom_range = 0.2,
                          horizontal_flip = True)

# %%
training_set1 = data1.flow_from_directory(directory=r'../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/',
                                                 target_size = (331, 331),
                                                 batch_size = 64,
                                                 subset = "training",
                                                 class_mode = 'categorical')
training_set2 = data2.flow_from_directory(directory=r'../working/cmyk/',
                                                 target_size = (331, 331),
                                                 batch_size = 64,
                                                 subset = "training",
                                                 class_mode = 'categorical')
training_set3 = data3.flow_from_directory(directory=r'../working/ycbcr/',
                                                 target_size = (331, 331),
                                                 batch_size = 64,
                                                 subset = "training",
                                                 class_mode = 'categorical')

# %%
test_set1 = data1.flow_from_directory('../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/',
                                            target_size = (331, 331),
                                            batch_size = 64,
                                            subset = "validation",
                                            class_mode = 'categorical')
test_set2 = data2.flow_from_directory('../working/cmyk/',
                                            target_size = (331, 331),
                                            batch_size = 64,
                                            subset = "validation",
                                            class_mode = 'categorical')
test_set3 = data3.flow_from_directory('../working/ycbcr/',
                                            target_size = (331, 331),
                                            batch_size = 64,
                                            subset = "validation",
                                            class_mode = 'categorical')

# %%
r1 = model1.fit(
  training_set1,
  validation_data=test_set1,
  epochs=15,
  steps_per_epoch=len(training_set1),
  validation_steps=len(test_set1)
)

# %%
r2 = model2.fit(
  training_set2,
  validation_data=test_set2,
  epochs=15,
  steps_per_epoch=len(training_set2),
  validation_steps=len(test_set2)
)

# %%
r3 = model3.fit(
  training_set3,
  validation_data=test_set3,
  epochs=15,
  steps_per_epoch=len(training_set3),
  validation_steps=len(test_set3)
)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(40,5))
plt.subplot(1, 5, 1)
plt.title('RGB')
plt.plot(r1.history['loss'], label='Train Loss')
plt.plot(r1.history['val_loss'], label='Val Loss')
plt.legend()
plt.subplot(1, 5, 2)
plt.title('CMYK')
plt.plot(r2.history['loss'], label='Train Loss')
plt.plot(r2.history['val_loss'], label='Val Loss')
plt.legend()
plt.subplot(1, 5, 3)
plt.title('YCbCr')
plt.plot(r3.history['loss'], label='Train Loss')
plt.plot(r3.history['val_loss'], label='Val Loss')
plt.legend()
plt.show()
plt.figure(figsize=(40,5))
plt.subplot(1, 5, 1)
plt.title('RGB')
plt.plot(r1.history['accuracy'], label='Train Accuracy')
plt.plot(r1.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.subplot(1, 5, 2)
plt.title('CMYK')
plt.plot(r2.history['accuracy'], label='Train Accuracy')
plt.plot(r2.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.subplot(1, 5, 3)
plt.title('YCbCr')
plt.plot(r3.history['accuracy'], label='Train Accuracy')
plt.plot(r3.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1.save('nasnetlargergb.h5')
model2.save('nasnetlargecmyk.h5')
model3.save('nasnetlargeycbcr.h5')

# %%
y_pred1 = model1.predict(test_set1)
y_pred11 = np.argmax(y_pred1, axis=1)
y_pred2 = model2.predict(test_set2)
y_pred22 = np.argmax(y_pred2, axis=1)
y_pred3 = model3.predict(test_set3)
y_pred33 = np.argmax(y_pred3, axis=1)

# %%
y1 = test_set1.classes
y2 = test_set2.classes
y3 = test_set3.classes

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse=False)
y1 = y1.reshape((3000, 1))
y_r = encoder.fit_transform(y1)

encoder = OneHotEncoder(sparse=False)
y2 = y2.reshape((3000, 1))
y_c = encoder.fit_transform(y2)

encoder = OneHotEncoder(sparse=False)
y3 = y3.reshape((3000, 1))
y_y = encoder.fit_transform(y3)

# %%
y_train = np.concatenate((y_pred1, y_pred2, y_pred3))
y_label = np.concatenate((y_r, y_c, y_y))

# %%
from sklearn import neighbors, datasets, preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

Xtrain, Xtest, y_tr, y_test = train_test_split(y_train, y_label, stratify = y_label, random_state = 0, train_size = 0.7)
print(y_tr.shape, y_test.shape)


knn = neighbors.KNeighborsClassifier(n_neighbors=1)
knn.fit(Xtrain, y_tr)
y_pred = knn.predict(Xtest)

print(accuracy_score(y_test, y_pred, normalize=False))
print(classification_report(y_test, y_pred))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_digits
from sklearn.model_selection import learning_curve
  
Xtrain, Xtest, y_tr, y_test = train_test_split(y_train, y_label, stratify = y_label, random_state = 0, train_size = 0.7)
  
# Obtain scores from learning curve function
# cv is the number of folds while performing Cross Validation
sizes, training_scores, testing_scores = learning_curve(KNeighborsClassifier(), Xtrain, y_tr, cv=10, scoring='accuracy', train_sizes=np.linspace(0.01, 1.0, 50))

# %%
# Mean and Standard Deviation of training scores
mean_training = np.mean(training_scores, axis=1)
Standard_Deviation_training = np.std(training_scores, axis=1)
  
# Mean and Standard Deviation of testing scores
mean_testing = np.mean(testing_scores, axis=1)
Standard_Deviation_testing = np.std(testing_scores, axis=1)
  
# dotted blue line is for training scores and green line is for cross-validation score
plt.plot(sizes, mean_training, '--', color="b",  label="Training score")
plt.plot(sizes, mean_testing, color="g", label="Cross-validation score")
  
# Drawing plot
plt.title("LEARNING CURVE FOR KNN Classifier")
plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %%
fpr, tpr, threshold = roc_curve(y_test, y_pred[:, 1])
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC Curve of kNN')
plt.show()

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=True,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, weight='bold', fontsize=16)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, fontsize=14)
    plt.yticks(tick_marks, classes, fontsize=14)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center", fontsize=12, weight='bold',
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontsize=16, weight='bold')
    plt.xlabel('Predicted label', fontsize=16, weight='bold')

# %%
cnf_matrix4 = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(40,5))
plt.title('kNN')
plot_confusion_matrix(cnf_matrix4, classes=['lung_aca', 'lung_n', 'lung_scc'],normalize=True,title='Normalized Confusion Matrix')

# %%
from sklearn.metrics import accuracy_score, classification_report

Y_pred1 = model1.predict(test_set1)
y_pred1 = np.argmax(Y_pred1, axis=1)
print(accuracy_score(test_set1.classes, y_pred1))
print(classification_report(test_set1.classes, y_pred1))

# %%
from sklearn.metrics import classification_report

Y_pred2 = model2.predict(test_set2)
y_pred2 = np.argmax(Y_pred2, axis=1)
print(classification_report(test_set2.classes, y_pred2))

# %%
from sklearn.metrics import classification_report

Y_pred3 = model3.predict(test_set3)
y_pred3 = np.argmax(Y_pred3, axis=1)

print(classification_report(test_set3.classes, y_pred3))

# %%
import itertools
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=True,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, weight='bold', fontsize=16)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, fontsize=14)
    plt.yticks(tick_marks, classes, fontsize=14)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center", fontsize=12, weight='bold',
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontsize=16, weight='bold')
    plt.xlabel('Predicted label', fontsize=16, weight='bold')

# %%
cnf_matrix1 = confusion_matrix(test_set1.classes, y_pred1)
cnf_matrix2 = confusion_matrix(test_set2.classes, y_pred2)
cnf_matrix3 = confusion_matrix(test_set3.classes, y_pred3)
np.set_printoptions(precision=2)
plt.figure(figsize=(40,5))
plt.subplot(1,5,1)
plt.title('RGB')
plot_confusion_matrix(cnf_matrix1, classes=['lung_aca', 'lung_n', 'lung_scc'],normalize=True,title='Normalized Confusion Matrix')
plt.subplot(1,5,2)
plt.title('CMYK')
plot_confusion_matrix(cnf_matrix2, classes=['lung_aca', 'lung_n', 'lung_scc'],normalize=True,title='Normalized Confusion Matrix')
plt.subplot(1,5,3)
plt.title('YCbCr')
plot_confusion_matrix(cnf_matrix3, classes=['lung_aca', 'lung_n', 'lung_scc'],normalize=True,title='Normalized Confusion Matrix')
plt.show()

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
img_size = (299, 299)

last_conv_layer_name = "normal_concat_18"
img_rgb = "../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/lung_n/lungn4125.jpeg"
img_cmyk = "../working/cmyk/lung_n/lungn3988.jpeg"
img_ycbcr = "../working/cmyk/lung_n/lungn3988.jpeg"

# %%
def get_img_array(img_path, size):
    img = keras.preprocessing.image.load_img(img_path, target_size=size)
    array = keras.preprocessing.image.img_to_array(img)
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]
    grads = tape.gradient(class_channel, last_conv_layer_output)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
img_rgb_array = preprocess_input(get_img_array(img_rgb, size=img_size))
img_cmyk_array = preprocess_input(get_img_array(img_cmyk, size=img_size))
img_ycbcr_array = preprocess_input(get_img_array(img_ycbcr, size=img_size))

# Make model
model_rgb = keras.model.load_model('nasnetlargergb.h5')
model_cmyk = keras.model.load_model('nasnetlargecmyk.h5')
model_ycbcr = keras.model.load_model('nasnetlargeycbcr.h5')


# Remove last layer's softmax
model_rgb.layers[-1].activation = None
model_cmyk.layers[-1].activation = None
model_ycbcr.layers[-1].activation = None

# Print what the top predicted class is
preds_rgb = model_rgb.predict(img_rgb_array)
preds_cmyk = model_rgb.predict(img_cmyk_array)
preds_ycbcr = model_rgb.predict(img_ycbcr_array)
print("Predicted:", decode_predictions(preds_rgb, top=1)[0])
print("Predicted:", decode_predictions(preds_cmyk, top=1)[0])
print("Predicted:", decode_predictions(preds_ycbcr, top=1)[0])
heatmap_rgb = make_gradcam_heatmap(img_rgb, model, last_conv_layer_name)
plt.matshow(heatmap_rgb)
heatmap_cmyk = make_gradcam_heatmap(img_cmyk, model, last_conv_layer_name)
plt.matshow(heatmap_cmyk)
heatmap_ycbcr = make_gradcam_heatmap(img_ycbcr, model, last_conv_layer_name)
plt.matshow(heatmap_ycbcr)
plt.show()

# %%
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)
    heatmap = np.uint8(255 * heatmap)
    jet = cm.get_cmap("jet")
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)
    superimposed_img.save(cam_path)
    display(Image(cam_path))
    

save_and_display_gradcam(img_rgb, heatmap_rgb)
save_and_display_gradcam(img_cmyk, heatmap_cmyk)
save_and_display_gradcam(img_ycbcr, heatmap_ycbcr)
