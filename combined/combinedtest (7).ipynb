# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.nasnet import NASNetLarge
from tensorflow.keras.applications.nasnet import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob

# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import matplotlib.image as mplimg
from matplotlib.pyplot import imshow
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from skimage import color
from skimage import io
from skimage.transform import rescale, resize
from keras import layers
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.imagenet_utils import preprocess_input
from keras.layers import Input, Dense, Activation, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalAveragePooling2D
from keras.models import Model
from keras.metrics import categorical_accuracy, top_k_categorical_accuracy, categorical_crossentropy
from keras.callbacks import ModelCheckpoint, EarlyStopping
import keras.backend as K
from keras.models import Sequential
import tensorflow as tf
import warnings

# %%
import os
f=[] 
def listdirs(rootdir):
    for file in os.listdir(rootdir):
        d = os.path.join(rootdir, file)
        if os.path.isdir(d):
            print(d)
            f.append(d)
            listdirs(d)
 
rootdir = '../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets'
listdirs(rootdir)
# Out:
# ../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/lung_aca
# ../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/lung_scc
# ../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/lung_n

# %%
import pandas as pd
from pathlib import Path

image_dir_path = '../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/lung_n'
paths = [path.parts[-3:] for path in
         Path(image_dir_path).rglob('*.jpeg')]
df1 = pd.DataFrame(data=paths, columns=['Root', 'Type', 'Images'])
print(df1)


image_dir_path = '../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/lung_scc'
paths = [path.parts[-3:] for path in
         Path(image_dir_path).rglob('*.jpeg')]
df2 = pd.DataFrame(data=paths, columns=['Root', 'Type', 'Images'])
print(df2)
image_dir_path ='../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/lung_aca'
paths = [path.parts[-3:] for path in
         Path(image_dir_path).rglob('*.jpeg')]
df3 = pd.DataFrame(data=paths, columns=['Root', 'Type', 'Images'])
print(df3)
# Out:
#                  Root    Type          Images
# 0     lung_image_sets  lung_n   lungn691.jpeg
# 1     lung_image_sets  lung_n  lungn3098.jpeg
# 2     lung_image_sets  lung_n  lungn4225.jpeg
# 3     lung_image_sets  lung_n    lungn40.jpeg
# 4     lung_image_sets  lung_n  lungn4213.jpeg
# ...               ...     ...             ...
# 4995  lung_image_sets  lung_n  lungn1469.jpeg
# 4996  lung_image_sets  lung_n  lungn1508.jpeg
# 4997  lung_image_sets  lung_n  lungn1966.jpeg
# 4998  lung_image_sets  lung_n  lungn4090.jpeg
# 4999  lung_image_sets  lung_n   lungn554.jpeg
#
# [5000 rows x 3 columns]
#                  Root      Type            Images
# 0     lung_image_sets  lung_scc  lungscc1930.jpeg
# 1     lung_image_sets  lung_scc  lungscc1441.jpeg
# 2     lung_image_sets  lung_scc  lungscc4624.jpeg
# 3     lung_image_sets  lung_scc  lungscc4038.jpeg
# 4     lung_image_sets  lung_scc  lungscc2504.jpeg
# ...               ...       ...               ...
# 4995  lung_image_sets  lung_scc  lungscc3958.jpeg
# 4996  lung_image_sets  lung_scc   lungscc770.jpeg
# 4997  lung_image_sets  lung_scc  lungscc4614.jpeg
# 4998  lung_image_sets  lung_scc  lungscc3515.jpeg
# 4999  lung_image_sets  lung_scc  lungscc1826.jpeg
#
# [5000 rows x 3 columns]
#                  Root      Type            Images
# 0     lung_image_sets  lung_aca  lungaca2056.jpeg
# 1     lung_image_sets  lung_aca  lungaca1914.jpeg
# 2     lung_image_sets  lung_aca  lungaca3989.jpeg
# 3     lung_image_sets  lung_aca  lungaca3803.jpeg
# 4     lung_image_sets  lung_aca   lungaca861.jpeg
# ...               ...       ...               ...
# 4995  lung_image_sets  lung_aca  lungaca3823.jpeg
# 4996  lung_image_sets  lung_aca  lungaca2457.jpeg
# 4997  lung_image_sets  lung_aca  lungaca4147.jpeg
# 4998  lung_image_sets  lung_aca  lungaca1477.jpeg
# 4999  lung_image_sets  lung_aca  lungaca3216.jpeg
#
# [5000 rows x 3 columns]

# %%
df = pd.concat([df1,df2,df3])
df.reset_index()
# Out:
#        index             Root      Type            Images
# 0          0  lung_image_sets    lung_n     lungn691.jpeg
# 1          1  lung_image_sets    lung_n    lungn3098.jpeg
# 2          2  lung_image_sets    lung_n    lungn4225.jpeg
# 3          3  lung_image_sets    lung_n      lungn40.jpeg
# 4          4  lung_image_sets    lung_n    lungn4213.jpeg
# ...      ...              ...       ...               ...
# 14995   4995  lung_image_sets  lung_aca  lungaca3823.jpeg
# 14996   4996  lung_image_sets  lung_aca  lungaca2457.jpeg
# 14997   4997  lung_image_sets  lung_aca  lungaca4147.jpeg
# 14998   4998  lung_image_sets  lung_aca  lungaca1477.jpeg
# 14999   4999  lung_image_sets  lung_aca  lungaca3216.jpeg
#
# [15000 rows x 4 columns]

# %%
import os
os.makedirs('/kaggle/working/cmyk/lung_n')
os.makedirs('/kaggle/working/cmyk/lung_scc')
os.makedirs('/kaggle/working/cmyk/lung_aca')
os.makedirs('/kaggle/working/ycbcr/lung_n')
os.makedirs('/kaggle/working/ycbcr/lung_scc')
os.makedirs('/kaggle/working/ycbcr/lung_aca')

# %%
y = df.filter(['Type'])

# %%
y
# Out:
#           Type
# 0       lung_n
# 1       lung_n
# 2       lung_n
# 3       lung_n
# 4       lung_n
# ...        ...
# 4995  lung_aca
# 4996  lung_aca
# 4997  lung_aca
# 4998  lung_aca
# 4999  lung_aca
#
# [15000 rows x 1 columns]

# %%
from zipfile import ZipFile
from PIL import Image
import os
def prepareImages(data, m, dataset):
    img_size=331
    print("Preparing images")
    X_train = np.zeros((m, img_size, img_size, 1))
    count = 0
    p=0
    for index,row in df.iterrows():
        img = image.load_img(r"../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/"+row["Type"]+"/"+row["Images"])
        img_rgb = Image.open(r"../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/"+row["Type"]+"/"+row["Images"])
        img_cmyk = img_rgb.convert('CMYK')
        img_ycbcr = img_rgb.convert('YCbCr')
        img_cmyk.save(r"./cmyk/"+y['Type'].values[count]+"/"+"processed"+str(count)+".jpeg")
        img_ycbcr.save(r"./ycbcr/"+y['Type'].values[count]+"/"+"processed"+str(count)+".jpeg")
        count += 1
        print(index)
        print(row)
        print(count)

# %%
df.shape[0]
# Out:
# 15000

# %%
prepareImages(df, df.shape[0], "train")
# Out:
# 4932
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1049.jpeg
# Name: 4932, dtype: object
# 9933
# 4933
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2776.jpeg
# Name: 4933, dtype: object
# 9934
# 4934
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3204.jpeg
# Name: 4934, dtype: object
# 9935
# 4935
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3177.jpeg
# Name: 4935, dtype: object
# 9936
# 4936
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4432.jpeg
# Name: 4936, dtype: object
# 9937
# 4937
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2235.jpeg
# Name: 4937, dtype: object
# 9938
# 4938
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3501.jpeg
# Name: 4938, dtype: object
# 9939
# 4939
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4462.jpeg
# Name: 4939, dtype: object
# 9940
# 4940
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3805.jpeg
# Name: 4940, dtype: object
# 9941
# 4941
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc857.jpeg
# Name: 4941, dtype: object
# 9942
# 4942
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1234.jpeg
# Name: 4942, dtype: object
# 9943
# 4943
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1497.jpeg
# Name: 4943, dtype: object
# 9944
# 4944
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1232.jpeg
# Name: 4944, dtype: object
# 9945
# 4945
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2596.jpeg
# Name: 4945, dtype: object
# 9946
# 4946
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2503.jpeg
# Name: 4946, dtype: object
# 9947
# 4947
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1408.jpeg
# Name: 4947, dtype: object
# 9948
# 4948
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3929.jpeg
# Name: 4948, dtype: object
# 9949
# 4949
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc922.jpeg
# Name: 4949, dtype: object
# 9950
# 4950
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1544.jpeg
# Name: 4950, dtype: object
# 9951
# 4951
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3844.jpeg
# Name: 4951, dtype: object
# 9952
# 4952
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3605.jpeg
# Name: 4952, dtype: object
# 9953
# 4953
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1274.jpeg
# Name: 4953, dtype: object
# 9954
# 4954
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc676.jpeg
# Name: 4954, dtype: object
# 9955
# 4955
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2680.jpeg
# Name: 4955, dtype: object
# 9956
# 4956
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4591.jpeg
# Name: 4956, dtype: object
# 9957
# 4957
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3422.jpeg
# Name: 4957, dtype: object
# 9958
# 4958
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3829.jpeg
# Name: 4958, dtype: object
# 9959
# 4959
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3424.jpeg
# Name: 4959, dtype: object
# 9960
# 4960
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1942.jpeg
# Name: 4960, dtype: object
# 9961
# 4961
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2515.jpeg
# Name: 4961, dtype: object
# 9962
# 4962
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4627.jpeg
# Name: 4962, dtype: object
# 9963
# 4963
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4475.jpeg
# Name: 4963, dtype: object
# 9964
# 4964
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc226.jpeg
# Name: 4964, dtype: object
# 9965
# 4965
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2098.jpeg
# Name: 4965, dtype: object
# 9966
# 4966
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1589.jpeg
# Name: 4966, dtype: object
# 9967
# 4967
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4864.jpeg
# Name: 4967, dtype: object
# 9968
# 4968
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2061.jpeg
# Name: 4968, dtype: object
# 9969
# 4969
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3908.jpeg
# Name: 4969, dtype: object
# 9970
# 4970
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2950.jpeg
# Name: 4970, dtype: object
# 9971
# 4971
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4535.jpeg
# Name: 4971, dtype: object
# 9972
# 4972
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3984.jpeg
# Name: 4972, dtype: object
# 9973
# 4973
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc201.jpeg
# Name: 4973, dtype: object
# 9974
# 4974
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2368.jpeg
# Name: 4974, dtype: object
# 9975
# 4975
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2273.jpeg
# Name: 4975, dtype: object
# 9976
# 4976
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc272.jpeg
# Name: 4976, dtype: object
# 9977
# 4977
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3386.jpeg
# Name: 4977, dtype: object
# 9978
# 4978
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2149.jpeg
# Name: 4978, dtype: object
# 9979
# 4979
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2371.jpeg
# Name: 4979, dtype: object
# 9980
# 4980
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3842.jpeg
# Name: 4980, dtype: object
# 9981
# 4981
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4427.jpeg
# Name: 4981, dtype: object
# 9982
# 4982
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc346.jpeg
# Name: 4982, dtype: object
# 9983
# 4983
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc956.jpeg
# Name: 4983, dtype: object
# 9984
# 4984
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1728.jpeg
# Name: 4984, dtype: object
# 9985
# 4985
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2303.jpeg
# Name: 4985, dtype: object
# 9986
# 4986
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4554.jpeg
# Name: 4986, dtype: object
# 9987
# 4987
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc255.jpeg
# Name: 4987, dtype: object
# 9988
# 4988
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1379.jpeg
# Name: 4988, dtype: object
# 9989
# 4989
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2631.jpeg
# Name: 4989, dtype: object
# 9990
# 4990
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4053.jpeg
# Name: 4990, dtype: object
# 9991
# 4991
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4065.jpeg
# Name: 4991, dtype: object
# 9992
# 4992
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2486.jpeg
# Name: 4992, dtype: object
# 9993
# 4993
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2283.jpeg
# Name: 4993, dtype: object
# 9994
# 4994
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc2630.jpeg
# Name: 4994, dtype: object
# 9995
# 4995
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3958.jpeg
# Name: 4995, dtype: object
# 9996
# 4996
# Root      lung_image_sets
# Type             lung_scc
# Images    lungscc770.jpeg
# Name: 4996, dtype: object
# 9997
# 4997
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc4614.jpeg
# Name: 4997, dtype: object
# 9998
# 4998
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc3515.jpeg
# Name: 4998, dtype: object
# 9999
# 4999
# Root       lung_image_sets
# Type              lung_scc
# Images    lungscc1826.jpeg
# Name: 4999, dtype: object
# 10000
# 0
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2056.jpeg
# Name: 0, dtype: object
# 10001
# 1
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1914.jpeg
# Name: 1, dtype: object
# 10002
# 2
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3989.jpeg
# Name: 2, dtype: object
# 10003
# 3
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3803.jpeg
# Name: 3, dtype: object
# 10004
# 4
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca861.jpeg
# Name: 4, dtype: object
# 10005
# 5
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4231.jpeg
# Name: 5, dtype: object
# 10006
# 6
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4646.jpeg
# Name: 6, dtype: object
# 10007
# 7
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4483.jpeg
# Name: 7, dtype: object
# 10008
# 8
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca918.jpeg
# Name: 8, dtype: object
# 10009
# 9
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca452.jpeg
# Name: 9, dtype: object
# 10010
# 10
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2826.jpeg
# Name: 10, dtype: object
# 10011
# 11
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4709.jpeg
# Name: 11, dtype: object
# 10012
# 12
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2491.jpeg
# Name: 12, dtype: object
# 10013
# 13
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3577.jpeg
# Name: 13, dtype: object
# 10014
# 14
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3764.jpeg
# Name: 14, dtype: object
# 10015
# 15
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2818.jpeg
# Name: 15, dtype: object
# 10016
# 16
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca224.jpeg
# Name: 16, dtype: object
# 10017
# 17
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4457.jpeg
# Name: 17, dtype: object
# 10018
# 18
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2906.jpeg
# Name: 18, dtype: object
# 10019
# 19
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2822.jpeg
# Name: 19, dtype: object
# 10020
# 20
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca312.jpeg
# Name: 20, dtype: object
# 10021
# 21
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca702.jpeg
# Name: 21, dtype: object
# 10022
# 22
# Root      lung_image_sets
# Type             lung_aca
# Images     lungaca81.jpeg
# Name: 22, dtype: object
# 10023
# 23
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1300.jpeg
# Name: 23, dtype: object
# 10024
# 24
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca677.jpeg
# Name: 24, dtype: object
# 10025
# 25
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4810.jpeg
# Name: 25, dtype: object
# 10026
# 26
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1596.jpeg
# Name: 26, dtype: object
# 10027
# 27
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2288.jpeg
# Name: 27, dtype: object
# 10028
# 28
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4993.jpeg
# Name: 28, dtype: object
# 10029
# 29
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4764.jpeg
# Name: 29, dtype: object
# 10030
# 30
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1058.jpeg
# Name: 30, dtype: object
# 10031
# 31
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2040.jpeg
# Name: 31, dtype: object
# 10032
# 32
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1572.jpeg
# Name: 32, dtype: object
# 10033
# 33
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4839.jpeg
# Name: 33, dtype: object
# 10034
# 34
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2218.jpeg
# Name: 34, dtype: object
# 10035
# 35
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3679.jpeg
# Name: 35, dtype: object
# 10036
# 36
# Root      lung_image_sets
# Type             lung_aca
# Images     lungaca94.jpeg
# Name: 36, dtype: object
# 10037
# 37
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2503.jpeg
# Name: 37, dtype: object
# 10038
# 38
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2074.jpeg
# Name: 38, dtype: object
# 10039
# 39
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1389.jpeg
# Name: 39, dtype: object
# 10040
# 40
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4568.jpeg
# Name: 40, dtype: object
# 10041
# 41
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3163.jpeg
# Name: 41, dtype: object
# 10042
# 42
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1929.jpeg
# Name: 42, dtype: object
# 10043
# 43
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2295.jpeg
# Name: 43, dtype: object
# 10044
# 44
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4241.jpeg
# Name: 44, dtype: object
# 10045
# 45
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1100.jpeg
# Name: 45, dtype: object
# 10046
# 46
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1531.jpeg
# Name: 46, dtype: object
# 10047
# 47
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2605.jpeg
# Name: 47, dtype: object
# 10048
# 48
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca789.jpeg
# Name: 48, dtype: object
# 10049
# 49
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca607.jpeg
# Name: 49, dtype: object
# 10050
# 50
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1561.jpeg
# Name: 50, dtype: object
# 10051
# 51
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2698.jpeg
# Name: 51, dtype: object
# 10052
# 52
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1637.jpeg
# Name: 52, dtype: object
# 10053
# 53
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3698.jpeg
# Name: 53, dtype: object
# 10054
# 54
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4614.jpeg
# Name: 54, dtype: object
# 10055
# 55
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4580.jpeg
# Name: 55, dtype: object
# 10056
# 56
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4438.jpeg
# Name: 56, dtype: object
# 10057
# 57
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3189.jpeg
# Name: 57, dtype: object
# 10058
# 58
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4355.jpeg
# Name: 58, dtype: object
# 10059
# 59
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4371.jpeg
# Name: 59, dtype: object
# 10060
# 60
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca223.jpeg
# Name: 60, dtype: object
# 10061
# 61
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3340.jpeg
# Name: 61, dtype: object
# 10062
# 62
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4338.jpeg
# Name: 62, dtype: object
# 10063
# 63
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca381.jpeg
# Name: 63, dtype: object
# 10064
# 64
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca220.jpeg
# Name: 64, dtype: object
# 10065
# 65
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2298.jpeg
# Name: 65, dtype: object
# 10066
# 66
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3348.jpeg
# Name: 66, dtype: object
# 10067
# 67
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4877.jpeg
# Name: 67, dtype: object
# 10068
# 68
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3093.jpeg
# Name: 68, dtype: object
# 10069
# 69
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4563.jpeg
# Name: 69, dtype: object
# 10070
# 70
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1804.jpeg
# Name: 70, dtype: object
# 10071
# 71
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3085.jpeg
# Name: 71, dtype: object
# 10072
# 72
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4517.jpeg
# Name: 72, dtype: object
# 10073
# 73
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1204.jpeg
# Name: 73, dtype: object
# 10074
# 74
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2587.jpeg
# Name: 74, dtype: object
# 10075
# 75
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4752.jpeg
# Name: 75, dtype: object
# 10076
# 76
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca179.jpeg
# Name: 76, dtype: object
# 10077
# 77
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1316.jpeg
# Name: 77, dtype: object
# 10078
# 78
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3258.jpeg
# Name: 78, dtype: object
# 10079
# 79
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1093.jpeg
# Name: 79, dtype: object
# 10080
# 80
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3674.jpeg
# Name: 80, dtype: object
# 10081
# 81
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3016.jpeg
# Name: 81, dtype: object
# 10082
# 82
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1603.jpeg
# Name: 82, dtype: object
# 10083
# 83
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2018.jpeg
# Name: 83, dtype: object
# 10084
# 84
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2304.jpeg
# Name: 84, dtype: object
# 10085
# 85
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3467.jpeg
# Name: 85, dtype: object
# 10086
# 86
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3057.jpeg
# Name: 86, dtype: object
# 10087
# 87
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1309.jpeg
# Name: 87, dtype: object
# 10088
# 88
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3429.jpeg
# Name: 88, dtype: object
# 10089
# 89
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3104.jpeg
# Name: 89, dtype: object
# 10090
# 90
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1275.jpeg
# Name: 90, dtype: object
# 10091
# 91
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2036.jpeg
# Name: 91, dtype: object
# 10092
# 92
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2085.jpeg
# Name: 92, dtype: object
# 10093
# 93
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca473.jpeg
# Name: 93, dtype: object
# 10094
# 94
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca383.jpeg
# Name: 94, dtype: object
# 10095
# 95
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4252.jpeg
# Name: 95, dtype: object
# 10096
# 96
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2759.jpeg
# Name: 96, dtype: object
# 10097
# 97
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2459.jpeg
# Name: 97, dtype: object
# 10098
# 98
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4065.jpeg
# Name: 98, dtype: object
# 10099
# 99
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3513.jpeg
# Name: 99, dtype: object
# 10100
# 100
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca132.jpeg
# Name: 100, dtype: object
# 10101
# 101
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2929.jpeg
# Name: 101, dtype: object
# 10102
# 102
# Root      lung_image_sets
# Type             lung_aca
# Images      lungaca7.jpeg
# Name: 102, dtype: object
# 10103
# 103
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1848.jpeg
# Name: 103, dtype: object
# 10104
# 104
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2157.jpeg
# Name: 104, dtype: object
# 10105
# 105
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3774.jpeg
# Name: 105, dtype: object
# 10106
# 106
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca310.jpeg
# Name: 106, dtype: object
# 10107
# 107
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4759.jpeg
# Name: 107, dtype: object
# 10108
# 108
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3061.jpeg
# Name: 108, dtype: object
# 10109
# 109
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2255.jpeg
# Name: 109, dtype: object
# 10110
# 110
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2997.jpeg
# Name: 110, dtype: object
# 10111
# 111
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca437.jpeg
# Name: 111, dtype: object
# 10112
# 112
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3666.jpeg
# Name: 112, dtype: object
# 10113
# 113
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4038.jpeg
# Name: 113, dtype: object
# 10114
# 114
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca556.jpeg
# Name: 114, dtype: object
# 10115
# 115
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2511.jpeg
# Name: 115, dtype: object
# 10116
# 116
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4779.jpeg
# Name: 116, dtype: object
# 10117
# 117
# Root      lung_image_sets
# Type             lung_aca
# Images     lungaca48.jpeg
# Name: 117, dtype: object
# 10118
# 118
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2021.jpeg
# Name: 118, dtype: object
# 10119
# 119
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca237.jpeg
# Name: 119, dtype: object
# 10120
# 120
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1190.jpeg
# Name: 120, dtype: object
# 10121
# 121
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca497.jpeg
# Name: 121, dtype: object
# 10122
# 122
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1370.jpeg
# Name: 122, dtype: object
# 10123
# 123
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2610.jpeg
# Name: 123, dtype: object
# 10124
# 124
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4934.jpeg
# Name: 124, dtype: object
# 10125
# 125
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3220.jpeg
# Name: 125, dtype: object
# 10126
# 126
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1783.jpeg
# Name: 126, dtype: object
# 10127
# 127
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca374.jpeg
# Name: 127, dtype: object
# 10128
# 128
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1995.jpeg
# Name: 128, dtype: object
# 10129
# 129
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1574.jpeg
# Name: 129, dtype: object
# 10130
# 130
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1084.jpeg
# Name: 130, dtype: object
# 10131
# 131
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4671.jpeg
# Name: 131, dtype: object
# 10132
# 132
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4689.jpeg
# Name: 132, dtype: object
# 10133
# 133
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1429.jpeg
# Name: 133, dtype: object
# 10134
# 134
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4597.jpeg
# Name: 134, dtype: object
# 10135
# 135
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2925.jpeg
# Name: 135, dtype: object
# 10136
# 136
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3634.jpeg
# Name: 136, dtype: object
# 10137
# 137
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1744.jpeg
# Name: 137, dtype: object
# 10138
# 138
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca159.jpeg
# Name: 138, dtype: object
# 10139
# 139
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4437.jpeg
# Name: 139, dtype: object
# 10140
# 140
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca555.jpeg
# Name: 140, dtype: object
# 10141
# 141
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1687.jpeg
# Name: 141, dtype: object
# 10142
# 142
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca527.jpeg
# Name: 142, dtype: object
# 10143
# 143
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3415.jpeg
# Name: 143, dtype: object
# 10144
# 144
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1696.jpeg
# Name: 144, dtype: object
# 10145
# 145
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4571.jpeg
# Name: 145, dtype: object
# 10146
# 146
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca968.jpeg
# Name: 146, dtype: object
# 10147
# 147
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1584.jpeg
# Name: 147, dtype: object
# 10148
# 148
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca957.jpeg
# Name: 148, dtype: object
# 10149
# 149
# Root      lung_image_sets
# Type             lung_aca
# Images     lungaca42.jpeg
# Name: 149, dtype: object
# 10150
# 150
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1786.jpeg
# Name: 150, dtype: object
# 10151
# 151
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca303.jpeg
# Name: 151, dtype: object
# 10152
# 152
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca337.jpeg
# Name: 152, dtype: object
# 10153
# 153
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2665.jpeg
# Name: 153, dtype: object
# 10154
# 154
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3095.jpeg
# Name: 154, dtype: object
# 10155
# 155
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2124.jpeg
# Name: 155, dtype: object
# 10156
# 156
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4440.jpeg
# Name: 156, dtype: object
# 10157
# 157
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3362.jpeg
# Name: 157, dtype: object
# 10158
# 158
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4754.jpeg
# Name: 158, dtype: object
# 10159
# 159
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca3676.jpeg
# Name: 159, dtype: object
# 10160
# 160
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1087.jpeg
# Name: 160, dtype: object
# 10161
# 161
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2442.jpeg
# Name: 161, dtype: object
# 10162
# 162
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca766.jpeg
# Name: 162, dtype: object
# 10163
# 163
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2632.jpeg
# Name: 163, dtype: object
# 10164
# 164
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4206.jpeg
# Name: 164, dtype: object
# 10165
# 165
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4874.jpeg
# Name: 165, dtype: object
# 10166
# 166
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca2131.jpeg
# Name: 166, dtype: object
# 10167
# 167
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4129.jpeg
# Name: 167, dtype: object
# 10168
# 168
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1937.jpeg
# Name: 168, dtype: object
# 10169
# 169
# Root      lung_image_sets
# Type             lung_aca
# Images    lungaca476.jpeg
# Name: 169, dtype: object
# 10170
# 170
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca1421.jpeg
# Name: 170, dtype: object
# 10171
# 171
# Root       lung_image_sets
# Type              lung_aca
# Images    lungaca4625.jpeg
# Name: 171, dtype: object
# 10172

# %%
IMAGE_SIZE = (331, 331, 3)

train_path_rgb = '../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets'
train_path_cmyk = '../working/cmyk/'
train_path_ycbcr = '..working/ycbcr/'

# %%
folders = glob('../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/*')
print(len(folders))

# %%
nasnetL1 = NASNetLarge(input_shape=IMAGE_SIZE, include_top=False, weights="imagenet")
nasnetL2 = NASNetLarge(input_shape=IMAGE_SIZE, include_top=False, weights="imagenet")
nasnetL3 = NASNetLarge(input_shape=IMAGE_SIZE, include_top=False, weights="imagenet")

# %%
for layer in nasnetL1.layers:
    layer.trainable = False
for layer in nasnetL2.layers:
    layer.trainable = False
for layer in nasnetL3.layers:
    layer.trainable = False

# %%
x1 = Flatten()(nasnetL1.output)
x2 = Flatten()(nasnetL2.output)
x3 = Flatten()(nasnetL3.output)

# %%
prediction1 = Dense(len(folders), activation='softmax')(x1)
prediction2 = Dense(len(folders), activation='softmax')(x2)
prediction3 = Dense(len(folders), activation='softmax')(x3)
model1 = Model(inputs=nasnetL1.input, outputs=prediction1)
model2 = Model(inputs=nasnetL2.input, outputs=prediction2)
model3 = Model(inputs=nasnetL3.input, outputs=prediction3)

# %%
model1.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)
model2.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)
model3.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
data1 = ImageDataGenerator(validation_split = 0.2,
                          rescale = 1./224,
                          shear_range = 0.2,
                          zoom_range = 0.2,
                          horizontal_flip = True)
data2 = ImageDataGenerator(validation_split = 0.2,
                          rescale = 1./224,
                          shear_range = 0.2,
                          zoom_range = 0.2,
                          horizontal_flip = True)
data3 = ImageDataGenerator(validation_split = 0.2,
                          rescale = 1./224,
                          shear_range = 0.2,
                          zoom_range = 0.2,
                          horizontal_flip = True)

# %%
training_set1 = data1.flow_from_directory(directory=r'../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/',
                                                 target_size = (331, 331),
                                                 batch_size = 64,
                                                 subset = "training",
                                                 class_mode = 'categorical')
training_set2 = data2.flow_from_directory(directory=r'../working/cmyk/',
                                                 target_size = (331, 331),
                                                 batch_size = 64,
                                                 subset = "training",
                                                 class_mode = 'categorical')
training_set3 = data3.flow_from_directory(directory=r'../working/ycbcr/',
                                                 target_size = (331, 331),
                                                 batch_size = 64,
                                                 subset = "training",
                                                 class_mode = 'categorical')

# %%
test_set1 = data1.flow_from_directory('../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/',
                                            target_size = (331, 331),
                                            batch_size = 64,
                                            subset = "validation",
                                            class_mode = 'categorical')
test_set2 = data2.flow_from_directory('../working/cmyk/',
                                            target_size = (331, 331),
                                            batch_size = 64,
                                            subset = "validation",
                                            class_mode = 'categorical')
test_set3 = data3.flow_from_directory('../working/ycbcr/',
                                            target_size = (331, 331),
                                            batch_size = 64,
                                            subset = "validation",
                                            class_mode = 'categorical')

# %%
r1 = model1.fit(
  training_set1,
  validation_data=test_set1,
  epochs=5,
  steps_per_epoch=len(training_set1),
  validation_steps=len(test_set1)
)

# %%
r2 = model2.fit(
  training_set2,
  validation_data=test_set2,
  epochs=5,
  steps_per_epoch=len(training_set2),
  validation_steps=len(test_set2)
)

# %%
r3 = model3.fit(
  training_set3,
  validation_data=test_set3,
  epochs=5,
  steps_per_epoch=len(training_set3),
  validation_steps=len(test_set3)
)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(40,5))
plt.subplot(1, 5, 1)
plt.title('RGB')
plt.plot(r1.history['loss'], label='Train Loss')
plt.plot(r1.history['val_loss'], label='Val Loss')
plt.legend()
plt.subplot(1, 5, 2)
plt.title('CMYK')
plt.plot(r2.history['loss'], label='Train Loss')
plt.plot(r2.history['val_loss'], label='Val Loss')
plt.legend()
plt.subplot(1, 5, 3)
plt.title('YCbCr')
plt.plot(r3.history['loss'], label='Train Loss')
plt.plot(r3.history['val_loss'], label='Val Loss')
plt.legend()
plt.show()
plt.figure(figsize=(40,5))
plt.subplot(1, 5, 1)
plt.title('RGB')
plt.plot(r1.history['accuracy'], label='Train Accuracy')
plt.plot(r1.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.subplot(1, 5, 2)
plt.title('CMYK')
plt.plot(r2.history['accuracy'], label='Train Accuracy')
plt.plot(r2.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.subplot(1, 5, 3)
plt.title('YCbCr')
plt.plot(r3.history['accuracy'], label='Train Accuracy')
plt.plot(r3.history['val_accuracy'], label='Val Accuracy')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import load_model
model1.save('nasnetlargergb.h5')
model2.save('nasnetlargecmyk.h5')
model3.save('nasnetlargeycbcr.h5')

# %%
y_pred1 = model1.predict(test_set1)
y_pred11 = np.argmax(y_pred1, axis=1)
y_pred2 = model2.predict(test_set2)
y_pred22 = np.argmax(y_pred2, axis=1)
y_pred3 = model3.predict(test_set3)
y_pred33 = np.argmax(y_pred3, axis=1)

# %%
y1 = test_set1.classes
y2 = test_set2.classes
y3 = test_set3.classes

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse=False)
y1 = y1.reshape((3000, 1))
y_r = encoder.fit_transform(y1)

encoder = OneHotEncoder(sparse=False)
y2 = y2.reshape((3000, 1))
y_c = encoder.fit_transform(y2)

encoder = OneHotEncoder(sparse=False)
y3 = y3.reshape((3000, 1))
y_y = encoder.fit_transform(y3)

# %%
y_train = np.concatenate((y_pred1, y_pred2, y_pred3))
y_label = np.concatenate((y_r, y_c, y_y))

# %%
from sklearn import neighbors, datasets, preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_curve, auc
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

Xtrain, Xtest, y_tr, y_test = train_test_split(y_train, y_label, stratify = y_label, random_state = 0, train_size = 0.7)
print(y_tr.shape, y_test.shape)


knn = neighbors.KNeighborsClassifier(n_neighbors=1)
knn.fit(Xtrain, y_tr)
y_pred = knn.predict(Xtest)

print(accuracy_score(y_test, y_pred, normalize=False))
print(classification_report(y_test, y_pred))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_digits
from sklearn.model_selection import learning_curve
  
Xtrain, Xtest, y_tr, y_test = train_test_split(y_train, y_label, stratify = y_label, random_state = 0, train_size = 0.7)
  
# Obtain scores from learning curve function
# cv is the number of folds while performing Cross Validation
sizes, training_scores, testing_scores = learning_curve(KNeighborsClassifier(), Xtrain, y_tr, cv=10, scoring='accuracy', train_sizes=np.linspace(0.01, 1.0, 50))

# %%
# Mean and Standard Deviation of training scores
mean_training = np.mean(training_scores, axis=1)
Standard_Deviation_training = np.std(training_scores, axis=1)
  
# Mean and Standard Deviation of testing scores
mean_testing = np.mean(testing_scores, axis=1)
Standard_Deviation_testing = np.std(testing_scores, axis=1)
  
# dotted blue line is for training scores and green line is for cross-validation score
plt.plot(sizes, mean_training, '--', color="b",  label="Training score")
plt.plot(sizes, mean_testing, color="g", label="Cross-validation score")
  
# Drawing plot
plt.title("LEARNING CURVE FOR KNN Classifier")
plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %%
fpr, tpr, threshold = roc_curve(y_test, y_pred[:, 1])
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC Curve of kNN')
plt.show()

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=True,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, weight='bold', fontsize=16)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, fontsize=14)
    plt.yticks(tick_marks, classes, fontsize=14)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center", fontsize=12, weight='bold',
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontsize=16, weight='bold')
    plt.xlabel('Predicted label', fontsize=16, weight='bold')

# %%
cnf_matrix4 = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(40,5))
plt.title('kNN')
plot_confusion_matrix(cnf_matrix4, classes=['lung_aca', 'lung_n', 'lung_scc'],normalize=True,title='Normalized Confusion Matrix')

# %%
from sklearn.metrics import accuracy_score, classification_report

Y_pred1 = model1.predict(test_set1)
y_pred1 = np.argmax(Y_pred1, axis=1)
print(accuracy_score(test_set1.classes, y_pred1))
print(classification_report(test_set1.classes, y_pred1))

# %%
from sklearn.metrics import classification_report

Y_pred2 = model2.predict(test_set2)
y_pred2 = np.argmax(Y_pred2, axis=1)
print(classification_report(test_set2.classes, y_pred2))

# %%
from sklearn.metrics import classification_report

Y_pred3 = model3.predict(test_set3)
y_pred3 = np.argmax(Y_pred3, axis=1)

print(classification_report(test_set3.classes, y_pred3))

# %%
import itertools
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=True,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, weight='bold', fontsize=16)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, fontsize=14)
    plt.yticks(tick_marks, classes, fontsize=14)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center", fontsize=12, weight='bold',
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontsize=16, weight='bold')
    plt.xlabel('Predicted label', fontsize=16, weight='bold')

# %%
cnf_matrix1 = confusion_matrix(test_set1.classes, y_pred1)
cnf_matrix2 = confusion_matrix(test_set2.classes, y_pred2)
cnf_matrix3 = confusion_matrix(test_set3.classes, y_pred3)
np.set_printoptions(precision=2)
plt.figure(figsize=(40,5))
plt.subplot(1,5,1)
plt.title('RGB')
plot_confusion_matrix(cnf_matrix1, classes=['lung_aca', 'lung_n', 'lung_scc'],normalize=True,title='Normalized Confusion Matrix')
plt.subplot(1,5,2)
plt.title('CMYK')
plot_confusion_matrix(cnf_matrix2, classes=['lung_aca', 'lung_n', 'lung_scc'],normalize=True,title='Normalized Confusion Matrix')
plt.subplot(1,5,3)
plt.title('YCbCr')
plot_confusion_matrix(cnf_matrix3, classes=['lung_aca', 'lung_n', 'lung_scc'],normalize=True,title='Normalized Confusion Matrix')
plt.show()

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

from IPython.display import Image, display
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %%
img_size = (299, 299)

last_conv_layer_name = "normal_concat_18"
img_rgb = "../input/lung-and-colon-cancer-histopathological-images/lung_colon_image_set/lung_image_sets/lung_n/lungn4125.jpeg"
img_cmyk = "../working/cmyk/lung_n/lungn3988.jpeg"
img_ycbcr = "../working/cmyk/lung_n/lungn3988.jpeg"

# %%
def get_img_array(img_path, size):
    img = keras.preprocessing.image.load_img(img_path, target_size=size)
    array = keras.preprocessing.image.img_to_array(img)
    # of size (1, 299, 299, 3)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]
    grads = tape.gradient(class_channel, last_conv_layer_output)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    last_conv_layer_output = last_conv_layer_output[0]
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# %%
img_rgb_array = preprocess_input(get_img_array(img_rgb, size=img_size))
img_cmyk_array = preprocess_input(get_img_array(img_cmyk, size=img_size))
img_ycbcr_array = preprocess_input(get_img_array(img_ycbcr, size=img_size))

# Make model
model_rgb = keras.model.load_model('nasnetlargergb.h5')
model_cmyk = keras.model.load_model('nasnetlargecmyk.h5')
model_ycbcr = keras.model.load_model('nasnetlargeycbcr.h5')


# Remove last layer's softmax
model_rgb.layers[-1].activation = None
model_cmyk.layers[-1].activation = None
model_ycbcr.layers[-1].activation = None

# Print what the top predicted class is
preds_rgb = model_rgb.predict(img_rgb_array)
preds_cmyk = model_rgb.predict(img_cmyk_array)
preds_ycbcr = model_rgb.predict(img_ycbcr_array)
print("Predicted:", decode_predictions(preds_rgb, top=1)[0])
print("Predicted:", decode_predictions(preds_cmyk, top=1)[0])
print("Predicted:", decode_predictions(preds_ycbcr, top=1)[0])
heatmap_rgb = make_gradcam_heatmap(img_rgb, model, last_conv_layer_name)
plt.matshow(heatmap_rgb)
heatmap_cmyk = make_gradcam_heatmap(img_cmyk, model, last_conv_layer_name)
plt.matshow(heatmap_cmyk)
heatmap_ycbcr = make_gradcam_heatmap(img_ycbcr, model, last_conv_layer_name)
plt.matshow(heatmap_ycbcr)
plt.show()

# %%
def save_and_display_gradcam(img_path, heatmap, cam_path="cam.jpg", alpha=0.4):
    img = keras.preprocessing.image.load_img(img_path)
    img = keras.preprocessing.image.img_to_array(img)
    heatmap = np.uint8(255 * heatmap)
    jet = cm.get_cmap("jet")
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)
    superimposed_img.save(cam_path)
    display(Image(cam_path))
    

save_and_display_gradcam(img_rgb, heatmap_rgb)
save_and_display_gradcam(img_cmyk, heatmap_cmyk)
save_and_display_gradcam(img_ycbcr, heatmap_ycbcr)
